# %% [markdown]
# # Build knowledge graph via deep learning
#
# ## Problem
# What are shared entities in all defi whitepapers?
#
# ## Solution
# With bag of words model, we will extract entities in whitepapers.
#
# ## Expected outcome
# 1. Top ten entities for each whitepaper are extracted.
# 2. Top ten trigram for each whitepaper are extracted.
#
# Authors:
# * Xiaoyuan Liu
# * Neel Kovelamudi
# * Zijian Xie
# * Mu He
# * Cuiqianhe Du
# * Nicholas Lin
# * Austin Wei
#
# Principal Investigator:
# * Dawn Song
#
# Date: Fall 2021
#
# References:
# [Bag_of_words](https://www.analyticsvidhya.com/blog/2021/08/a-friendly-guide-to-nlp-bag-of-words-with-python-example/)

# %% [markdown]
# ### Import library

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import collections
import re
import os
import string
pd.set_option('display.max_colwidth', 200)
from sklearn.feature_extraction.text import CountVectorizer

# %%
#!pip install BeautifulSoup4
# import nltk
# nltk.download()  # Download text data sets, including stop words

# %%
# Import BeautifulSoup into your workspace
from bs4 import BeautifulSoup

# %%
from nltk.corpus import stopwords # Import the stop word list
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# ### Whitepaper datasource

# %%
def read_whitepapers(filename):
    directory = "../whitepapers/top20_whitepapers/"
    texts = []
    for entry in os.scandir(directory):
        if (entry.path.endswith(filename) and entry.is_file()):
            a_dataframe = pd.read_csv(entry.path, names=[filename], sep="\n")
    a_dataframe.replace('', np.nan, inplace=True)
    a_dataframe.dropna(inplace=True)
    return a_dataframe

# %%
# bitcoin_filename="Bitcoin.txt"
# whitepapers = read_whitepapers(bitcoin_filename)
# # whitepapers.rename(columns={bitcoin_filename: "whitepapers"}, inplace=True)
# whitepapers

# %%
filenames = ['Algorand.txt', 'Avalanche.txt', 'Binance.txt', 'Bitcoin.txt', 'Cardano.txt', 'Chainlink.txt',
            'Crypto_com.txt', 'Ethereum.txt', 'FTX_token.txt', 'PolkaDot.txt', 'Polygon.txt', 'Ripple.txt', 
            'Solana.txt', 'Terra.txt', 'Tether.txt', 'Tron.txt', 'Uniswap.txt', 'Wrapped.txt']

# %%
def create_dataframe():
#     for i in filenames:
#         whitepaper = read_whitepapers(i)
#         whitepaper.rename(columns={i : "whitepapers"}, inplace=True)
#         whitepapers = whitepapers.append(whitepaper)
    df_from_each_whitepaper = (read_whitepapers(i) for i in filenames)
    whitepapers = pd.concat(df_from_each_whitepaper, ignore_index=True, axis=1)
    return whitepapers

# %% [markdown]
# ### Create dataframe
# Append whitepaper dataframe one after another

# %%
df_whitepapers = create_dataframe()
df_whitepapers.columns = filenames
df_whitepapers
# Out:
#                                                   Algorand.txt  \
# 0                                           ALGORAND AGREEMENT
# 1       Super Fast and Partition Resilient Byzantine Agreement
# 2     Jing Chen Sergey Gorbunov Silvio Micali Georgios Vlachos
# 3                {jing, sergey, silvio, georgios@algorand.com}
# 4                                               April 25, 2018
# ...                                                        ...
# 5327                                                       NaN
# 5328                                                       NaN
# 5329                                                       NaN
# 5330                                                       NaN
# 5331                                                       NaN
#
#                                                                                             Avalanche.txt  \
# 0                                                                                      Avalanche Platform
# 1                                                                                              2020/06/30
# 2                                      Kevin Sekniqi, Daniel Laine, Stephen Buttolph, and Emin Gu¨n Sirer
# 3               Abstract. ThispaperprovidesanarchitecturaloverviewoftheﬁrstreleaseoftheAvalancheplatform,
# 4     5 codenamed Avalanche Borealis. For details on the economics of the native token, labeled $AVAX, we
# ...                                                                                                   ...
# 5327                                                                                                  NaN
# 5328                                                                                                  NaN
# 5329                                                                                                  NaN
# 5330                                                                                                  NaN
# 5331                                                                                                  NaN
#
#             Binance.txt  \
# 0     Binance Exchange
# 1      www.binance.com
# 2           Whitepaper
# 3                 V1.2
# 4              Intro 3
# ...                 ...
# 5327                NaN
# 5328                NaN
# 5329                NaN
# 5330                NaN
# 5331                NaN
#
#                                                                            Bitcoin.txt  \
# 0                                       Bitcoin: A Peer-to-Peer Electronic Cash System
# 1                                                                     Satoshi Nakamoto
# 2                                                                     satoshin@gmx.com
# 3                                                                      www.bitcoin.org
# 4     Abstract.   A purely peer-to-peer version of electronic cash would allow online
# ...                                                                                ...
# 5327                                                                               NaN
# 5328                                                                               NaN
# 5329                                                                               NaN
# 5330                                                                               NaN
# 5331                                                                               NaN
#
#                                                                                  Cardano.txt  \
# 0                            Ouroboros: A Provably Secure Proof-of-Stake Blockchain Protocol
# 1                       Aggelos Kiayias∗ Alexander Russell† Bernardo David‡ Roman Oliynykov§
# 2                                                                              July 20, 2019
# 3                                                                                   Abstract
# 4     We present “Ouroboros,” the ﬁrst blockchain protocol based on proof of stake with rig-
# ...                                                                                      ...
# 5327                                                                                     NaN
# 5328                                                                                     NaN
# 5329                                                                                     NaN
# 5330                                                                                     NaN
# 5331                                                                                     NaN
#
#                                                                          Chainlink.txt  \
# 0                                        Chainlink 2.0: Next Steps in the Evolution of
# 1                                                        Decentralized Oracle Networks
# 2                                 Lorenz Breidenbach1 Christian Cachin2 Benedict Chan1
# 3                           Alex Coventry1 Steve Ellis1 Ari Juels3 Farinaz Koushanfar4
# 4                                       Andrew Miller5 Brendan Magauran1 Daniel Moroz6
# ...                                                                                ...
# 5327                                                                             tion.
# 5328  • Customization: Diﬀerent users may have diﬀerent preferences in terms of trade-
# 5329      oﬀs among reliability, performance, and cost tradeoﬀs, and should be able to
# 5330               express these preferences in terms of their selection of providers.
# 5331                                                                               136
#
#                                                                    Crypto_com.txt  \
# 0                                                      Crypto.com Whitepaper 1.03
# 1                                                                     August 2020
# 2                                                    Version 1.03.17 - April 2021
# 3     This whitepaper is a working document that is subject to review and changes
# 4                                                                    Crypto.com 2
# ...                                                                           ...
# 5327                                                                          NaN
# 5328                                                                          NaN
# 5329                                                                          NaN
# 5330                                                                          NaN
# 5331                                                                          NaN
#
#                                                                                                Ethereum.txt  \
# 0                                                                                         HOME / WHITEPAPER
# 1                                                                       Page last updated: January 30, 2022
# 2                                                                                              On this page
# 3                                                                                       Ethereum Whitepaper
# 4     This introductory paper was originally published in 2013 by Vitalik Buterin, the founder of Ethereum,
# ...                                                                                                     ...
# 5327                                                                                                    NaN
# 5328                                                                                                    NaN
# 5329                                                                                                    NaN
# 5330                                                                                                    NaN
# 5331                                                                                                    NaN
#
#                          FTX_token.txt  \
# 0                       FTT Whitepaper
# 1     Initially Released June 25, 2019
# 2                                    1
# 3                             Contents
# 4                      1 Our Mission 4
# ...                                ...
# 5327                               NaN
# 5328                               NaN
# 5329                               NaN
# 5330                               NaN
# 5331                               NaN
#
#                                                     PolkaDot.txt  \
# 0     POLKADOT: VISION FOR A HETEROGENEOUS MULTI-CHAIN FRAMEWORK
# 1                                                        DRAFT 1
# 2                                                   DR.GAVINWOOD
# 3                                        FOUNDER,ETHEREUM&PARITY
# 4                                                GAVIN@PARITY.IO
# ...                                                          ...
# 5327                                                         NaN
# 5328                                                         NaN
# 5329                                                         NaN
# 5330                                                         NaN
# 5331                                                         NaN
#
#                                                        Polygon.txt  \
# 0          Search or jump to… Pulls Issues Marketplace Explore
# 1                                        maticnetwork / whitepaper
# 2                          Public  Watch  12   Fork  29  Star  125
# 3     Code Issues 3 Pull requests 1 Actions Projects Wiki Security
# 4                        master  whitepaper / README.md Go to file
# ...                                                            ...
# 5327                                                           NaN
# 5328                                                           NaN
# 5329                                                           NaN
# 5330                                                           NaN
# 5331                                                           NaN
#
#                                                                                                          Ripple.txt  \
# 0                                                                                                RippleLabsInc,2014
# 1                                                                           The Ripple Protocol Consensus Algorithm
# 2                                                                                                    David Schwartz
# 3                            This paper does not reflect the current state of the ledger consensus protocol or its
# 4     david@ripple.com analysis. We will continue hosting this draft for historical interest, but it SHOULD NOT be
# ...                                                                                                             ...
# 5327                                                                                                            NaN
# 5328                                                                                                            NaN
# 5329                                                                                                            NaN
# 5330                                                                                                            NaN
# 5331                                                                                                            NaN
#
#                                                                               Solana.txt  \
# 0                                                  Solana: A new architecture for a high
# 1                                                         performance blockchain v0.8.14
# 2                                                                      Anatoly Yakovenko
# 3                                                                      anatoly@solana.io
# 4     Legal Disclaimer NothinginthisWhitePaperisanoffertosell,orthesolicitationofanoffer
# ...                                                                                  ...
# 5327                                                                                 NaN
# 5328                                                                                 NaN
# 5329                                                                                 NaN
# 5330                                                                                 NaN
# 5331                                                                                 NaN
#
#                                                        Terra.txt Tether.txt  \
# 0                                                   Terra Money:
# 1                                         Stability and Adoption
# 2     Evan Kereiakes, Do Kwon, Marco Di Maggio, Nicholas Platias
# 3                                                     April 2019
# 4                                                       Abstract
# ...                                                          ...        ...
# 5327                                                         NaN        NaN
# 5328                                                         NaN        NaN
# 5329                                                         NaN        NaN
# 5330                                                         NaN        NaN
# 5331                                                         NaN        NaN
#
#                                          Tron.txt  \
# 0     Advanced Decentralized Blockchain Platform
# 1                        Whitepaper Version: 2.0
# 2                     TRON Protocol Version: 3.2
# 3                                       TRON DAO
# 4             December 10th, 2018, San Francisco
# ...                                           ...
# 5327                                          NaN
# 5328                                          NaN
# 5329                                          NaN
# 5330                                          NaN
# 5331                                          NaN
#
#                                                Uniswap.txt  \
# 0                                          Uniswap v2 Core
# 1               Hayden Adams Noah Zinsmeister Dan Robinson
# 2     hayden@uniswap.org noah@uniswap.org dan@paradigm.xyz
# 3                                               March 2020
# 4                                                 Abstract
# ...                                                    ...
# 5327                                                   NaN
# 5328                                                   NaN
# 5329                                                   NaN
# 5330                                                   NaN
# 5331                                                   NaN
#
#                                                     Wrapped.txt
# 0
# 1                                               Wrapped Tokens
# 2     A multi-institutional framework for tokenizing any asset
# 3
# 4                                              Whitepaper v0.2
# ...                                                         ...
# 5327                                                        NaN
# 5328                                                        NaN
# 5329                                                        NaN
# 5330                                                        NaN
# 5331                                                        NaN
#
# [5332 rows x 18 columns]

# %% [markdown]
# ### Data cleaning/preprocessing

# %%
def sentence_to_words(sentence):
    # Function to convert a raw sentence to a string of words
    # The input is a single string (a whitepaper sentence), and 
    # the output is a single string (a preprocessed sentence)
    
    # if the line is nah, return
    if pd.isnull(sentence):
        return sentence
    # 1. Remove HTML
    sentence = BeautifulSoup(sentence).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", sentence) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
for i in filenames:
    df_whitepapers[i] = df_whitepapers[i].apply(lambda x: sentence_to_words(x))
df_whitepapers
# Out:
#                                                   Algorand.txt  \
# 0                                           algorand agreement
# 1           super fast partition resilient byzantine agreement
# 2     jing chen sergey gorbunov silvio micali georgios vlachos
# 3                     jing sergey silvio georgios algorand com
# 4                                                        april
# ...                                                        ...
# 5327                                                       NaN
# 5328                                                       NaN
# 5329                                                       NaN
# 5330                                                       NaN
# 5331                                                       NaN
#
#                                                                                 Avalanche.txt  \
# 0                                                                          avalanche platform
# 1
# 2                                 kevin sekniqi daniel laine stephen buttolph emin gu n sirer
# 3     abstract thispaperprovidesanarchitecturaloverviewofthe rstreleaseoftheavalancheplatform
# 4                    codenamed avalanche borealis details economics native token labeled avax
# ...                                                                                       ...
# 5327                                                                                      NaN
# 5328                                                                                      NaN
# 5329                                                                                      NaN
# 5330                                                                                      NaN
# 5331                                                                                      NaN
#
#            Binance.txt  \
# 0     binance exchange
# 1      www binance com
# 2           whitepaper
# 3                    v
# 4                intro
# ...                ...
# 5327               NaN
# 5328               NaN
# 5329               NaN
# 5330               NaN
# 5331               NaN
#
#                                                                Bitcoin.txt  \
# 0                                 bitcoin peer peer electronic cash system
# 1                                                         satoshi nakamoto
# 2                                                         satoshin gmx com
# 3                                                          www bitcoin org
# 4     abstract purely peer peer version electronic cash would allow online
# ...                                                                    ...
# 5327                                                                   NaN
# 5328                                                                   NaN
# 5329                                                                   NaN
# 5330                                                                   NaN
# 5331                                                                   NaN
#
#                                                            Cardano.txt  \
# 0            ouroboros provably secure proof stake blockchain protocol
# 1     aggelos kiayias alexander russell bernardo david roman oliynykov
# 2                                                                 july
# 3                                                             abstract
# 4      present ouroboros rst blockchain protocol based proof stake rig
# ...                                                                ...
# 5327                                                               NaN
# 5328                                                               NaN
# 5329                                                               NaN
# 5330                                                               NaN
# 5331                                                               NaN
#
#                                                           Chainlink.txt  \
# 0                                        chainlink next steps evolution
# 1                                         decentralized oracle networks
# 2                     lorenz breidenbach christian cachin benedict chan
# 3                alex coventry steve ellis ari juels farinaz koushanfar
# 4                           andrew miller brendan magauran daniel moroz
# ...                                                                 ...
# 5327                                                               tion
# 5328  customization di erent users may di erent preferences terms trade
# 5329                     among reliability performance cost tradeo able
# 5330                      express preferences terms selection providers
# 5331
#
#                                           Crypto_com.txt  \
# 0                                  crypto com whitepaper
# 1                                                 august
# 2                                          version april
# 3     whitepaper working document subject review changes
# 4                                             crypto com
# ...                                                  ...
# 5327                                                 NaN
# 5328                                                 NaN
# 5329                                                 NaN
# 5330                                                 NaN
# 5331                                                 NaN
#
#                                                                   Ethereum.txt  \
# 0                                                              home whitepaper
# 1                                                    page last updated january
# 2                                                                         page
# 3                                                          ethereum whitepaper
# 4     introductory paper originally published vitalik buterin founder ethereum
# ...                                                                        ...
# 5327                                                                       NaN
# 5328                                                                       NaN
# 5329                                                                       NaN
# 5330                                                                       NaN
# 5331                                                                       NaN
#
#                 FTX_token.txt  \
# 0              ftt whitepaper
# 1     initially released june
# 2
# 3                    contents
# 4                     mission
# ...                       ...
# 5327                      NaN
# 5328                      NaN
# 5329                      NaN
# 5330                      NaN
# 5331                      NaN
#
#                                              PolkaDot.txt  \
# 0     polkadot vision heterogeneous multi chain framework
# 1                                                   draft
# 2                                            dr gavinwood
# 3                                 founder ethereum parity
# 4                                         gavin parity io
# ...                                                   ...
# 5327                                                  NaN
# 5328                                                  NaN
# 5329                                                  NaN
# 5330                                                  NaN
# 5331                                                  NaN
#
#                                                    Polygon.txt  \
# 0                 search jump pulls issues marketplace explore
# 1                                      maticnetwork whitepaper
# 2                                       public watch fork star
# 3     code issues pull requests actions projects wiki security
# 4                          master whitepaper readme md go file
# ...                                                        ...
# 5327                                                       NaN
# 5328                                                       NaN
# 5329                                                       NaN
# 5330                                                       NaN
# 5331                                                       NaN
#
#                                                                 Ripple.txt  \
# 0                                                            ripplelabsinc
# 1                                      ripple protocol consensus algorithm
# 2                                                           david schwartz
# 3                    paper reflect current state ledger consensus protocol
# 4     david ripple com analysis continue hosting draft historical interest
# ...                                                                    ...
# 5327                                                                   NaN
# 5328                                                                   NaN
# 5329                                                                   NaN
# 5330                                                                   NaN
# 5331                                                                   NaN
#
#                                                                               Solana.txt  \
# 0                                                           solana new architecture high
# 1                                                               performance blockchain v
# 2                                                                      anatoly yakovenko
# 3                                                                      anatoly solana io
# 4     legal disclaimer nothinginthiswhitepaperisanoffertosell orthesolicitationofanoffer
# ...                                                                                  ...
# 5327                                                                                 NaN
# 5328                                                                                 NaN
# 5329                                                                                 NaN
# 5330                                                                                 NaN
# 5331                                                                                 NaN
#
#                                                  Terra.txt Tether.txt  \
# 0                                              terra money
# 1                                       stability adoption
# 2     evan kereiakes kwon marco di maggio nicholas platias
# 3                                                    april
# 4                                                 abstract
# ...                                                    ...        ...
# 5327                                                   NaN        NaN
# 5328                                                   NaN        NaN
# 5329                                                   NaN        NaN
# 5330                                                   NaN        NaN
# 5331                                                   NaN        NaN
#
#                                         Tron.txt  \
# 0     advanced decentralized blockchain platform
# 1                             whitepaper version
# 2                          tron protocol version
# 3                                       tron dao
# 4                      december th san francisco
# ...                                          ...
# 5327                                         NaN
# 5328                                         NaN
# 5329                                         NaN
# 5330                                         NaN
# 5331                                         NaN
#
#                                                Uniswap.txt  \
# 0                                           uniswap v core
# 1               hayden adams noah zinsmeister dan robinson
# 2     hayden uniswap org noah uniswap org dan paradigm xyz
# 3                                                    march
# 4                                                 abstract
# ...                                                    ...
# 5327                                                   NaN
# 5328                                                   NaN
# 5329                                                   NaN
# 5330                                                   NaN
# 5331                                                   NaN
#
#                                          Wrapped.txt
# 0
# 1                                     wrapped tokens
# 2     multi institutional framework tokenizing asset
# 3
# 4                                       whitepaper v
# ...                                              ...
# 5327                                             NaN
# 5328                                             NaN
# 5329                                             NaN
# 5330                                             NaN
# 5331                                             NaN
#
# [5332 rows x 18 columns]

# %%
def fit(vectorizer, df_column):
    # Function to fit a vectorizer to whitepaper
    # The input is vectorizer, and a df_column (whitepaper)
    # the output is a list of top 10 occurence
    # fit a column
    df_column.dropna(inplace=True)
    features = vectorizer.fit_transform(df_column)
    vocabulary = vectorizer.get_feature_names()
    features = features.toarray()
    
    # Sum up the counts of each vocabulary word
    count_sum = np.sum(features, axis=0)

    # For each, print the vocabulary word and the number of times it 
    # appears in the training set
    paired =  list(zip(vocabulary, count_sum))
    
    # reverse sort occurence of words
    feat_occ = sorted(paired, key = lambda x: x[1], reverse=True)
    return pd.DataFrame(list(feat_occ))

# %% [markdown]
# ### CountVectorizer

# %%
vectorizer1 = CountVectorizer(stop_words='english')

# %% [markdown]
# ### Count of each word in the vocabulary

# %%
bow_occ_from_each_whitepaper = (fit(vectorizer1, df_whitepapers[i]) for i in filenames)
df_bow_occ = pd.concat(bow_occ_from_each_whitepaper, ignore_index=True, axis=1)
df_bow_columns = [val for val in filenames for _ in (0, 1)]
df_bow_occ.columns = [i if not c % 2 else "count" for c, i in enumerate(df_bow_columns)]
df_bow_occ[:10]
# Out:
#   Algorand.txt  count Avalanche.txt  count Binance.txt  count   Bitcoin.txt  \
# 0       period  103.0     avalanche   57.0     binance   32.0         block
# 1          cid   79.0       network   31.0    exchange   29.0          hash
# 2       honest   67.0      platform   31.0     systems   23.0   transaction
# 3        votes   65.0     protocols   28.0         bnb   22.0  transactions
# 4        value   62.0     consensus   27.0     trading   20.0         nodes
# 5        users   61.0         nodes   25.0        team   19.0         proof
# 6         step   56.0         state   25.0     founder   18.0          work
# 7     protocol   37.0           set   24.0   bijietech   17.0         chain
# 8         time   36.0          avax   23.0          cz   17.0      attacker
# 9         user   36.0          node   21.0   exchanges   15.0       network
#
#    count Cardano.txt  count  ...  Terra.txt  count  Tether.txt  count  \
# 0   51.0         cid  264.0  ...      terra   79.0      tether   66.0
# 1   43.0    protocol  227.0  ...     mining   50.0     tethers   57.0
# 2   37.0      honest  194.0  ...       luna   48.0        fiat   56.0
# 3   32.0          sl  148.0  ...      price   40.0     bitcoin   52.0
# 4   31.0       stake  143.0  ...    rewards   37.0       users   42.0
# 5   27.0       chain  136.0  ...    funding   27.0    exchange   36.0
# 6   27.0        slot  129.0  ...       unit   26.0    currency   32.0
# 7   25.0        fork  123.0  ...   currency   24.0   exchanges   28.0
# 8   22.0       slots  104.0  ...  stability   24.0     limited   25.0
# 9   21.0      length  102.0  ...     stable   24.0  blockchain   23.0
#
#       Tron.txt  count Uniswap.txt  count Wrapped.txt  count
# 0         tron  105.0     uniswap   47.0      tokens   68.0
# 1          trx   82.0    contract   45.0     wrapped   48.0
# 2      network   72.0       price   35.0        wbtc   44.0
# 3        block   69.0   liquidity   33.0    merchant   43.0
# 4      account   65.0         eth   32.0        user   30.0
# 5    bandwidth   43.0        pair   28.0       chain   28.0
# 6        token   43.0        pool   20.0       asset   27.0
# 7  transaction   43.0       asset   19.0   custodian   26.0
# 8     contract   41.0      tokens   17.0    ethereum   26.0
# 9        smart   41.0      assets   16.0       token   25.0
#
# [10 rows x 36 columns]

# %% [markdown]
# ### Count of shared entities among whitepapers

# %%
# First create a dictionary with key: whitepaper, value: list of words in df
dict_bow = df_bow_occ[filenames].dropna().to_dict('list')

# %%
# Then reverse the dictionary to have key: words, value: list of whitepaper
dict_bow_rev = {}
for k,v in dict_bow.items():
    for x in v:
        dict_bow_rev.setdefault(x,[]).append(k)

# Sort the dictionary with len of whitepapers' list
dict_bow_rev = dict(sorted(dict_bow_rev.items(), key=lambda item: len(item[1]), reverse=True)) 
# dict_bow_rev

# %%
# Count occurence of each word
dict_bow_count = {}

for key, values in dict_bow_rev.items():
    dict_bow_count[key] = len(values)

# Sort by occurence
dict_bow_count = dict(sorted(dict_bow_count.items(), key=lambda item: item[1], reverse=True))
# dict_bow_count

# %% [markdown]
# ### Actual result
# The previous column shows top 10 occurence in bag of words model among 20 whitepapers

# %% [markdown]
# ### Trigram

# %%
vectorizer2 = CountVectorizer(stop_words='english',ngram_range=(3, 3))

# %% [markdown]
# ### Count of each word in the vocabulary

# %%
tri_occ_from_each_whitepaper = (fit(vectorizer2, df_whitepapers[i]) for i in filenames)
df_tri_occ = pd.concat(tri_occ_from_each_whitepaper, ignore_index=True, axis=1)
df_tri_columns = [val for val in filenames for _ in (0, 1)]
df_tri_occ.columns = [i if not c % 2 else "count" for c, i in enumerate(df_tri_columns)]
df_tri_occ[:10]
# Out:
#            Algorand.txt  count               Avalanche.txt  count  \
# 0           cid cid cid   17.0            buttolph emin gu    8.0
# 1        certi ed value   10.0        daniel laine stephen    8.0
# 2       votes value cid    9.0               emin gu sirer    8.0
# 3      soft votes value    8.0        kevin sekniqi daniel    8.0
# 4       ed value period    7.0      laine stephen buttolph    8.0
# 5  potentially certi ed    7.0        sekniqi daniel laine    8.0
# 6      value cid period    6.0       stephen buttolph emin    8.0
# 7     honest users cert    5.0  forward looking statements    6.0
# 8   honest users period    5.0   post quantum cryptography    3.0
# 9       sees soft votes    5.0           blockchain ned vm    2.0
#
#                 Binance.txt  count         Bitcoin.txt  count  \
# 0              july th july    4.0      hash hash hash    7.0
# 1                th july th    4.0     prev hash nonce    7.0
# 2         allan yan product    2.0            tx tx tx    5.0
# 3          binance coin bnb    2.0  block header block    4.0
# 4              bnb pay fees    2.0     hash nonce prev    4.0
# 5            bnb value burn    2.0     nonce prev hash    4.0
# 6          bnb vesting plan    2.0    proof work chain    4.0
# 7        changpeng zhao ceo    2.0  majority cpu power    3.0
# 8           cz years worked    2.0   owner owner owner    3.0
# 9  english chinese japanese    2.0    proof work block    3.0
#
#                 Cardano.txt  count  ...                  Terra.txt  count  \
# 0               cid cid cid   23.0  ...        unit mining rewards   17.0
# 1                  sl sl sl   15.0  ...             fees luna burn    4.0
# 2               cid exp cid    9.0  ...             rate luna burn    4.0
# 3              cid lexp cid    9.0  ...        changes unit mining    3.0
# 4  leader selection process    9.0  ...       long term commitment    3.0
# 5           closed fork let    7.0  ...           long term stable    3.0
# 6    computer science pages    7.0  ...             luna burn rate    3.0
# 7               exp cid cid    7.0  ...       target exchange rate    3.0
# 8    lecture notes computer    7.0  ...     available mining power    2.0
# 9    notes computer science    7.0  ...  central banks governments    2.0
#
#                        Tether.txt  count                    Tron.txt  count  \
# 0           audit flaws exchanges    4.0        tron virtual machine   11.0
# 1        custodian reserve assets    4.0         virtual machine tvm    8.0
# 2           existing fiat pegging    4.0          create new account    7.0
# 3              fiat currency held    4.0  dynamic network parameters    7.0
# 4            fiat pegging systems    4.0       delegated proof stake    5.0
# 5         flaws exchanges wallets    4.0            false notice set    5.0
# 6       limitations existing fiat    4.0            notice set false    5.0
# 7             omni layer protocol    4.0              set false true    5.0
# 8          currency held reserves    3.0           total vote reward    5.0
# 9  decentralized digital currency    3.0           true false notice    5.0
#
#             Uniswap.txt  count            Wrapped.txt  count
# 0  liquidity pool share    6.0    asset backed tokens    6.0
# 1     asset terms asset    3.0   atomic swap contract    3.0
# 2       basis point fee    3.0     erc token ethereum    3.0
# 3             cid ti pi    3.0     new wrapped tokens    3.0
# 4   https eips ethereum    3.0    address secret hash    2.0
# 5          org eips eip    3.0     aml kyc procedures    2.0
# 6     price asset terms    3.0        asset case wbtc    2.0
# 7        url https eips    3.0        atomic swap fee    2.0
# 8  value liquidity pool    3.0        atomic swap use    2.0
# 9         angeris et al    2.0  backed tokens usually    2.0
#
# [10 rows x 36 columns]

# %% [markdown]
# ### Count of shared trigram among whitepapers

# %%
# First create a dictionary with key: whitepaper, value: list of words in df
dict_tri = df_tri_occ[filenames].dropna().to_dict('list')

# %%
# Then reverse the dictionary to have key: words, value: list of whitepaper
dict_tri_rev = {}
for k,v in dict_tri.items():
    for x in v:
        dict_tri_rev.setdefault(x,[]).append(k)

# Sort the dictionary with len of whitepapers' list
dict_tri_rev = dict(sorted(dict_tri_rev.items(), key=lambda item: len(item[1]), reverse=True)) 
dict_tri_rev
# Out:
# {'anti money laundering': ['Binance.txt',
#   'Crypto_com.txt',
#   'Tether.txt',
#   'Wrapped.txt'],
#  'https github com': ['Cardano.txt',
#   'PolkaDot.txt',
#   'Polygon.txt',
#   'Tron.txt'],
#  'cid cid cid': ['Algorand.txt', 'Cardano.txt', 'Chainlink.txt'],
#  'publicly veri able': ['Algorand.txt', 'Cardano.txt', 'Chainlink.txt'],
#  'bitcoin peer peer': ['Avalanche.txt', 'Bitcoin.txt', 'Ripple.txt'],
#  'ethereum virtual machine': ['Avalanche.txt', 'Ethereum.txt', 'Tron.txt'],
#  'en wikipedia org': ['Binance.txt', 'Tether.txt', 'Tron.txt'],
#  'block header block': ['Bitcoin.txt', 'Ethereum.txt', 'Tron.txt'],
#  'eth usd price': ['Chainlink.txt', 'Ethereum.txt', 'Uniswap.txt'],
#  'wikipedia org wiki': ['Chainlink.txt', 'Tether.txt', 'Tron.txt'],
#  'bitcoin org bitcoin': ['PolkaDot.txt', 'Tether.txt', 'Tron.txt'],
#  'able random functions': ['Algorand.txt', 'Chainlink.txt'],
#  'arxiv org abs': ['Algorand.txt', 'Ripple.txt'],
#  'public secret key': ['Algorand.txt', 'Cardano.txt'],
#  'veri able random': ['Algorand.txt', 'Chainlink.txt'],
#  'cryptology eprint archive': ['Algorand.txt', 'Cardano.txt'],
#  'eprint archive report': ['Algorand.txt', 'Cardano.txt'],
#  'forward looking statements': ['Avalanche.txt', 'Crypto_com.txt'],
#  'computational resources required': ['Avalanche.txt', 'Polygon.txt'],
#  'deploy smart contracts': ['Avalanche.txt', 'Tron.txt'],
#  'based trading volume': ['Binance.txt', 'Crypto_com.txt'],
#  'https en wikipedia': ['Binance.txt', 'Tron.txt'],
#  'hash hash hash': ['Bitcoin.txt', 'Solana.txt'],
#  'proof work block': ['Bitcoin.txt', 'Ethereum.txt'],
#  'allowing willing parties': ['Bitcoin.txt', 'Tether.txt'],
#  'based cryptographic proof': ['Bitcoin.txt', 'Tether.txt'],
#  'block header transactions': ['Bitcoin.txt', 'Tron.txt'],
#  'computer communications security': ['Bitcoin.txt', 'Chainlink.txt'],
#  'computer science pages': ['Bitcoin.txt', 'Cardano.txt'],
#  'cryptographic proof instead': ['Bitcoin.txt', 'Tether.txt'],
#  'directly need trusted': ['Bitcoin.txt', 'Tether.txt'],
#  'electronic payment based': ['Bitcoin.txt', 'Tether.txt'],
#  'ieee computer society': ['Bitcoin.txt', 'Cardano.txt'],
#  'able secret sharing': ['Cardano.txt', 'Chainlink.txt'],
#  'long range attacks': ['Cardano.txt', 'Solana.txt'],
#  'advances cryptology crypto': ['Cardano.txt', 'Chainlink.txt'],
#  'based blockchain protocols': ['Cardano.txt', 'Polygon.txt'],
#  'https medium com': ['Chainlink.txt', 'Polygon.txt'],
#  'https www coindesk': ['Chainlink.txt', 'Wrapped.txt'],
#  'eips ethereum org': ['Chainlink.txt', 'Uniswap.txt'],
#  'ethereum org eips': ['Chainlink.txt', 'Uniswap.txt'],
#  'https eips ethereum': ['Chainlink.txt', 'Uniswap.txt'],
#  'blog ethereum org': ['Chainlink.txt', 'Solana.txt'],
#  'https ssrn com': ['Chainlink.txt', 'Terra.txt'],
#  'play key role': ['Chainlink.txt', 'Wrapped.txt'],
#  'ssrn com abstract': ['Chainlink.txt', 'Terra.txt'],
#  'chief operating officer': ['Crypto_com.txt', 'Polygon.txt'],
#  'allows users pay': ['Crypto_com.txt', 'Polygon.txt'],
#  'attacks consensus based': ['Crypto_com.txt', 'Polygon.txt'],
#  'attacks denial service': ['Crypto_com.txt', 'Polygon.txt'],
#  'attacks smurfing spoofing': ['Crypto_com.txt', 'Polygon.txt'],
#  'attacks sybil attacks': ['Crypto_com.txt', 'Polygon.txt'],
#  'based attacks sybil': ['Crypto_com.txt', 'Polygon.txt'],
#  'algorithm public key': ['Ethereum.txt', 'Tron.txt'],
#  'consensus mechanism proof': ['PolkaDot.txt', 'Tron.txt'],
#  'high transaction fees': ['Polygon.txt', 'Wrapped.txt'],
#  'delegated proof stake': ['Solana.txt', 'Tron.txt'],
#  'certi ed value': ['Algorand.txt'],
#  'votes value cid': ['Algorand.txt'],
#  'soft votes value': ['Algorand.txt'],
#  'ed value period': ['Algorand.txt'],
#  'potentially certi ed': ['Algorand.txt'],
#  'value cid period': ['Algorand.txt'],
#  'honest users cert': ['Algorand.txt'],
#  'honest users period': ['Algorand.txt'],
#  'sees soft votes': ['Algorand.txt'],
#  'user following clock': ['Algorand.txt'],
#  'certi ed period': ['Algorand.txt'],
#  'honest users nish': ['Algorand.txt'],
#  'period honest users': ['Algorand.txt'],
#  'period leader cid': ['Algorand.txt'],
#  'propagates period credential': ['Algorand.txt'],
#  'proposes propagates period': ['Algorand.txt'],
#  'received votes period': ['Algorand.txt'],
#  'received votes value': ['Algorand.txt'],
#  'step user following': ['Algorand.txt'],
#  'time honest users': ['Algorand.txt'],
#  'users start period': ['Algorand.txt'],
#  'votes value period': ['Algorand.txt'],
#  'honest users start': ['Algorand.txt'],
#  'honest users vote': ['Algorand.txt'],
#  'identi es leader': ['Algorand.txt'],
#  'leader cid period': ['Algorand.txt'],
#  'period unique potential': ['Algorand.txt'],
#  'potential starting value': ['Algorand.txt'],
#  'soft vote step': ['Algorand.txt'],
#  'soft votes time': ['Algorand.txt'],
#  'starting value period': ['Algorand.txt'],
#  'step honest users': ['Algorand.txt'],
#  'time time apart': ['Algorand.txt'],
#  'unique potential starting': ['Algorand.txt'],
#  'users try agree': ['Algorand.txt'],
#  'value period signature': ['Algorand.txt'],
#  'value period value': ['Algorand.txt'],
#  'vote value period': ['Algorand.txt'],
#  'votes honest users': ['Algorand.txt'],
#  'agreement protocol leader': ['Algorand.txt'],
#  'agreement reached constant': ['Algorand.txt'],
#  'byzantine agreement protocol': ['Algorand.txt'],
#  'case honest users': ['Algorand.txt'],
#  'cert vote value': ['Algorand.txt'],
#  'cert voted step': ['Algorand.txt'],
#  'cert votes malicious': ['Algorand.txt'],
#  'cert votes value': ['Algorand.txt'],
#  'certi ed potentially': ['Algorand.txt'],
#  'cid cert votes': ['Algorand.txt'],
#  'cid honest honest': ['Algorand.txt'],
#  'cid period soft': ['Algorand.txt'],
#  'communication setting players': ['Algorand.txt'],
#  'di erent outputs': ['Algorand.txt'],
#  'ed potentially certi': ['Algorand.txt'],
#  'es leader cid': ['Algorand.txt'],
#  'essentially copies step': ['Algorand.txt'],
#  'fast recovery network': ['Algorand.txt'],
#  'finishing step user': ['Algorand.txt'],
#  'gorbunov silvio micali': ['Algorand.txt'],
#  'helped propagating soft': ['Algorand.txt'],
#  'honest honest users': ['Algorand.txt'],
#  'honest users end': ['Algorand.txt'],
#  'honest users partition': ['Algorand.txt'],
#  'honest users receive': ['Algorand.txt'],
#  'honest users voted': ['Algorand.txt'],
#  'http arxiv org': ['Algorand.txt'],
#  'leader cid malicious': ['Algorand.txt'],
#  'messages sent honest': ['Algorand.txt'],
#  'micali georgios vlachos': ['Algorand.txt'],
#  'network setting communication': ['Algorand.txt'],
#  'original algorand protocol': ['Algorand.txt'],
#  'period finishing step': ['Algorand.txt'],
#  'period propagates sig': ['Algorand.txt'],
#  'period receive votes': ['Algorand.txt'],
#  'period second finishing': ['Algorand.txt'],
#  'period soft votes': ['Algorand.txt'],
#  'period value cert': ['Algorand.txt'],
#  'propagating soft votes': ['Algorand.txt'],
#  'protocol communication setting': ['Algorand.txt'],
#  'protocol di erent': ['Algorand.txt'],
#  'protocol leader election': ['Algorand.txt'],
#  'recovery network partition': ['Algorand.txt'],
#  'second finishing step': ['Algorand.txt'],
#  'secret key pair': ['Algorand.txt'],
#  'seen votes period': ['Algorand.txt'],
#  'sees votes period': ['Algorand.txt'],
#  'sergey gorbunov silvio': ['Algorand.txt'],
#  'setting players communicate': ['Algorand.txt'],
#  'shortly partition resolved': ['Algorand.txt'],
#  'silvio micali algorand': ['Algorand.txt'],
#  'silvio micali georgios': ['Algorand.txt'],
#  'soft votes honest': ['Algorand.txt'],
#  'soft votes leader': ['Algorand.txt'],
#  'start period time': ['Algorand.txt'],
#  'step certifying step': ['Algorand.txt'],
#  'step filtering step': ['Algorand.txt'],
#  'step honest user': ['Algorand.txt'],
#  'step period finishing': ['Algorand.txt'],
#  'step period second': ['Algorand.txt'],
#  'step value proposal': ['Algorand.txt'],
#  'steps essentially copies': ['Algorand.txt'],
#  'try agree value': ['Algorand.txt'],
#  'user identi es': ['Algorand.txt'],
#  'user starts period': ['Algorand.txt'],
#  'user votes value': ['Algorand.txt'],
#  'users cert vote': ['Algorand.txt'],
#  'users cert voted': ['Algorand.txt'],
#  'users end step': ['Algorand.txt'],
#  'users nish protocol': ['Algorand.txt'],
#  'users soft vote': ['Algorand.txt'],
#  'users voted step': ['Algorand.txt'],
#  'value cert voted': ['Algorand.txt'],
#  'value certi ed': ['Algorand.txt'],
#  'value cid cert': ['Algorand.txt'],
#  'value period propagates': ['Algorand.txt'],
#  'value period votes': ['Algorand.txt'],
#  'value potentially certi': ['Algorand.txt'],
#  'value proposed cid': ['Algorand.txt'],
#  'votes malicious users': ['Algorand.txt'],
#  'votes value proposed': ['Algorand.txt'],
#  'able corrupt users': ['Algorand.txt'],
#  'able jointly serviced': ['Algorand.txt'],
#  'able nish period': ['Algorand.txt'],
#  'able track time': ['Algorand.txt'],
#  'aby end step': ['Algorand.txt'],
#  'accepted signature relative': ['Algorand.txt'],
#  'access public random': ['Algorand.txt'],
#  'achieves desired properties': ['Algorand.txt'],
#  'achieves following desirable': ['Algorand.txt'],
#  'actual block received': ['Algorand.txt'],
#  'actual blocks protocol': ['Algorand.txt'],
#  'adaptive chosen message': ['Algorand.txt'],
#  'adaptively instantaneously control': ['Algorand.txt'],
#  'add steps numbered': ['Algorand.txt'],
#  'adding cert votes': ['Algorand.txt'],
#  'adversary adversary perfectly': ['Algorand.txt'],
#  'adversary case votes': ['Algorand.txt'],
#  'adversary complete control': ['Algorand.txt'],
#  'adversary corrupt users': ['Algorand.txt'],
#  'adversary forge honest': ['Algorand.txt'],
#  'adversary fully controls': ['Algorand.txt'],
#  'adversary make certi': ['Algorand.txt'],
#  'adversary perfectly coordinates': ['Algorand.txt'],
#  'adversary permissionless settings': ['Algorand.txt'],
#  'adversary turn potentially': ['Algorand.txt'],
#  'aevenifdi erentusersstartperiod hoursapartintime': ['Algorand.txt'],
#  'aftertheblockpropagates acerti cateisgenerated': ['Algorand.txt'],
#  'agree block transactions': ['Algorand.txt'],
#  'agreement leader election': ['Algorand.txt'],
#  'agreement network bounded': ['Algorand.txt'],
#  'agreement protocol works': ['Algorand.txt'],
#  'agreement quickly network': ['Algorand.txt'],
#  'agreements agreement protocol': ['Algorand.txt'],
#  'agreements cryptocurrencies sosp': ['Algorand.txt'],
#  'agreements users try': ['Algorand.txt'],
#  'algorand arxiv report': ['Algorand.txt'],
#  'algorand blockchain proposed': ['Algorand.txt'],
#  'algorand blockchain users': ['Algorand.txt'],
#  'algorand cient democratic': ['Algorand.txt'],
#  'algorand ledger based': ['Algorand.txt'],
#  'algorand protocol adversary': ['Algorand.txt'],
#  'align communication setting': ['Algorand.txt'],
#  'allows change set': ['Algorand.txt'],
#  'allows users soft': ['Algorand.txt'],
#  'apart invariant remains': ['Algorand.txt'],
#  'apart wearebackintheno partition': ['Algorand.txt'],
#  'applies blockchains permissionless': ['Algorand.txt'],
#  'arbitrarily partitioned unknown': ['Algorand.txt'],
#  'arbitrary network partitions': ['Algorand.txt'],
#  'arbitrary partition resilience': ['Algorand.txt'],
#  'argmin sig set': ['Algorand.txt'],
#  'arxiv report http': ['Algorand.txt'],
#  'aslongasiremainsinthesameperiod clock keepscounting': ['Algorand.txt'],
#  'assumptions manuscript simplify': ['Algorand.txt'],
#  'assumptions soon relaxed': ['Algorand.txt'],
#  'asynchronous networks algorand': ['Algorand.txt'],
#  'asynchronous safety network': ['Algorand.txt'],
#  'attacks enjoy following': ['Algorand.txt'],
#  'beginning protocol set': ['Algorand.txt'],
#  'block transactions rst': ['Algorand.txt'],
#  'block transactions similarly': ['Algorand.txt'],
#  'blockchain proposed values': ['Algorand.txt'],
#  'blockchain users agree': ['Algorand.txt'],
#  'blocks hashes soft': ['Algorand.txt'],
#  'blocks propagated parallel': ['Algorand.txt'],
#  'blocks protocol allows': ['Algorand.txt'],
#  'bound agreement reached': ['Algorand.txt'],
#  'bounded delay agreement': ['Algorand.txt'],
#  'bounded delay honest': ['Algorand.txt'],
#  'bounded message delay': ['Algorand.txt'],
#  'break hash function': ['Algorand.txt'],
#  'brie discuss protocol': ['Algorand.txt'],
#  'bwhenthenetworkisnotpartitioned anhonestuseralwaysgoesthroughperiodsinorder duringapartition': ['Algorand.txt'],
#  'byzantine agreement leader': ['Algorand.txt'],
#  'byzantine agreements cryptocurrencies': ['Algorand.txt'],
#  'byzantine agreements users': ['Algorand.txt'],
#  'case votes propagated': ['Algorand.txt'],
#  'cases honest users': ['Algorand.txt'],
#  'cate partition honest': ['Algorand.txt'],
#  'cate produced voting': ['Algorand.txt'],
#  'cate time partition': ['Algorand.txt'],
#  'cate voting step': ['Algorand.txt'],
#  'cert vote moment': ['Algorand.txt'],
#  'cert vote time': ['Algorand.txt'],
#  'cert vote user': ['Algorand.txt'],
#  'cert voted helped': ['Algorand.txt'],
#  'cert voted nish': ['Algorand.txt'],
#  'cert voted potentially': ['Algorand.txt'],
#  'cert voted users': ['Algorand.txt'],
#  'cert voted value': ['Algorand.txt'],
#  'cert votes form': ['Algorand.txt'],
#  'cert votes period': ['Algorand.txt'],
#  'cert votes sees': ['Algorand.txt'],
#  'certi cate partition': ['Algorand.txt'],
#  'certi cate produced': ['Algorand.txt'],
#  'certi cate time': ['Algorand.txt'],
#  'certi cate voting': ['Algorand.txt'],
#  'certi ed adding': ['Algorand.txt'],
#  'certi ed unique': ['Algorand.txt'],
#  'certifying step user': ['Algorand.txt'],
#  'change set users': ['Algorand.txt'],
#  'changes lead protocol': ['Algorand.txt'],
#  'chen sergey gorbunov': ['Algorand.txt'],
#  'chen silvio micali': ['Algorand.txt'],
#  'chooses messages sent': ['Algorand.txt'],
#  'chosen message attacks': ['Algorand.txt'],
#  'cid certi ed': ['Algorand.txt'],
#  'cid cid start': ['Algorand.txt'],
#  'cid honest users': ['Algorand.txt'],
#  'cid leader step': ['Algorand.txt'],
#  'cid malicious protocol': ['Algorand.txt'],
#  'cid period user': ['Algorand.txt'],
#  'cid period voted': ['Algorand.txt'],
#  'cid period votes': ['Algorand.txt'],
#  'cid propose private': ['Algorand.txt'],
#  'cid proposes step': ['Algorand.txt'],
#  'cid seen votes': ['Algorand.txt'],
#  'cid sees votes': ['Algorand.txt'],
#  'cid sets cid': ['Algorand.txt'],
#  'cid soft votes': ['Algorand.txt'],
#  'cid start period': ['Algorand.txt'],
#  'cid user sets': ['Algorand.txt'],
#  'cient democratic ledger': ['Algorand.txt'],
#  'clarity loop step': ['Algorand.txt'],
#  'classic literature byzantine': ['Algorand.txt'],
#  'clock keepscounting theusers': ['Algorand.txt'],
#  'clock resets time': ['Algorand.txt'],
#  'clocks individual timers': ['Algorand.txt'],
#  'combined step separate': ['Algorand.txt'],
#  'combining facts period': ['Algorand.txt'],
#  'committee members use': ['Algorand.txt'],
#  'committee selection manuscript': ['Algorand.txt'],
#  'committees committee members': ['Algorand.txt'],
#  'committees order make': ['Algorand.txt'],
#  'communicate propagation network': ['Algorand.txt'],
#  'communicate steps synchronous': ['Algorand.txt'],
#  'communication setting omitted': ['Algorand.txt'],
#  'communication setting steps': ['Algorand.txt'],
#  'compared period honest': ['Algorand.txt'],
#  'complete control message': ['Algorand.txt'],
#  'conceptual clarity loop': ['Algorand.txt'],
#  'concrete network setting': ['Algorand.txt'],
#  'condition communication setting': ['Algorand.txt'],
#  'conditions committee selection': ['Algorand.txt'],
#  'constant expected time': ['Algorand.txt'],
#  'control message delivery': ['Algorand.txt'],
#  'coordinates malicious players': ['Algorand.txt'],
#  'copies step odd': ['Algorand.txt'],
#  'corresponding conditions committee': ['Algorand.txt'],
#  'corresponding rule moving': ['Algorand.txt'],
#  'corrupt users adaptively': ['Algorand.txt'],
#  'corrupt users dynamically': ['Algorand.txt'],
#  'corrupt users instantaneously': ['Algorand.txt'],
#  'corrupted partition sending': ['Algorand.txt'],
#  'count short xed': ['Algorand.txt'],
#  'credential period sig': ['Algorand.txt'],
#  'credential user credential': ['Algorand.txt'],
#  'cryptocurrency cryptology eprint': ['Algorand.txt'],
#  'cryptographic primitives shall': ['Algorand.txt'],
#  'cryptographic self selection': ['Algorand.txt'],
#  'cryptographic tools hash': ['Algorand.txt'],
#  'delay agreement reached': ['Algorand.txt'],
#  'delay honest messages': ['Algorand.txt'],
#  'delivered honest users': ['Algorand.txt'],
#  'delivery messages network': ['Algorand.txt'],
#  'delivery orders di': ['Algorand.txt'],
#  'democoin publicly veri': ['Algorand.txt'],
#  'democratic ledger arxiv': ['Algorand.txt'],
#  'denote signature string': ['Algorand.txt'],
#  'denoted special symbol': ['Algorand.txt'],
#  'dependence honesty ratio': ['Algorand.txt'],
#  'depending fast block': ['Algorand.txt'],
#  'describes random string': ['Algorand.txt'],
#  'desirable properties described': ['Algorand.txt'],
#  'desirable properties honest': ['Algorand.txt'],
#  'desired properties given': ['Algorand.txt'],
#  'desired properties protocol': ['Algorand.txt'],
#  'di erent messages': ['Algorand.txt'],
#  'di erent users': ['Algorand.txt'],
#  'digital signature scheme': ['Algorand.txt'],
#  'digital signatures precisely': ['Algorand.txt'],
#  'discuss protocol applies': ['Algorand.txt'],
#  'dynamic adversary permissionless': ['Algorand.txt'],
#  'dynamically small committees': ['Algorand.txt'],
#  'ectively aftertheblockpropagates acerti': ['Algorand.txt'],
#  'ed adding cert': ['Algorand.txt'],
#  'ed period cert': ['Algorand.txt'],
#  'ed period honest': ['Algorand.txt'],
#  'ed period receive': ['Algorand.txt'],
#  'ed unique value': ['Algorand.txt'],
#  'ed value adding': ['Algorand.txt'],
#  'ed value certi': ['Algorand.txt'],
#  'ed value cid': ['Algorand.txt'],
#  'election users try': ['Algorand.txt'],
#  'end step honest': ['Algorand.txt'],
#  'end step messages': ['Algorand.txt'],
#  'end step user': ['Algorand.txt'],
#  'ensure signer identities': ['Algorand.txt'],
#  'ephemeral keys sign': ['Algorand.txt'],
#  'erent messages messages': ['Algorand.txt'],
#  'erent users private': ['Algorand.txt'],
#  'erentusersstartperiod hoursapartintime itisasifthenetworkhasbeenpartitionedand': ['Algorand.txt'],
#  'es cid leader': ['Algorand.txt'],
#  'es leader period': ['Algorand.txt'],
#  'especially adversary complete': ['Algorand.txt'],
#  'execution permissionless protocol': ['Algorand.txt'],
#  'exist values votes': ['Algorand.txt'],
#  'exist votes honest': ['Algorand.txt'],
#  'exists certi ed': ['Algorand.txt'],
#  'expected time particular': ['Algorand.txt'],
#  'extra time compared': ['Algorand.txt'],
#  'facts period leader': ['Algorand.txt'],
#  'fast agreement network': ['Algorand.txt'],
#  'fast agreement partition': ['Algorand.txt'],
#  'fast block propagates': ['Algorand.txt'],
#  'fast byzantine agreement': ['Algorand.txt'],
#  'fast partition resilient': ['Algorand.txt'],
#  'fast partition resolved': ['Algorand.txt'],
#  'filtering step user': ['Algorand.txt'],
#  'follow leader soft': ['Algorand.txt'],
#  'following assumptions soon': ['Algorand.txt'],
#  'following classic literature': ['Algorand.txt'],
#  'following desirable properties': ['Algorand.txt'],
#  'following properties hold': ['Algorand.txt'],
#  'forge honest players': ['Algorand.txt'],
#  'forhistoricalreferences extensions andevaluationofalgorandledgerwerefertheinterestedreadersto': ['Algorand.txt'],
#  'form certi cate': ['Algorand.txt'],
#  'function modeled random': ['Algorand.txt'],
#  'functions vrfs constructed': ['Algorand.txt'],
#  'future periods cid': ['Algorand.txt'],
#  'generalized permissionless setting': ['Algorand.txt'],
#  'generally certi ed': ['Algorand.txt'],
#  'generated updated blockchain': ['Algorand.txt'],
#  'georgios algorand com': ['Algorand.txt'],
#  'georgios vlachos nickolai': ['Algorand.txt'],
#  'gilad rotem hemo': ['Algorand.txt'],
#  'given time bound': ['Algorand.txt'],
#  'guaranteed votes value': ['Algorand.txt'],
#  'guarantees desirable properties': ['Algorand.txt'],
#  'halting condition communication': ['Algorand.txt'],
#  'halts moment sees': ['Algorand.txt'],
#  'happens leader cid': ['Algorand.txt'],
#  'happens timers reset': ['Algorand.txt'],
#  'hashes blocks propagated': ['Algorand.txt'],
#  'hashes soft votes': ['Algorand.txt'],
#  'hashes step seeing': ['Algorand.txt'],
#  'helped propagating cert': ['Algorand.txt'],
#  'hemo silvio micali': ['Algorand.txt'],
#  'highest period honest': ['Algorand.txt'],
#  'highlighted introduction concrete': ['Algorand.txt'],
#  'holds secret key': ['Algorand.txt'],
#  'honest honest user': ['Algorand.txt'],
#  'honest leader proposes': ['Algorand.txt'],
#  'honest majority following': ['Algorand.txt'],
#  'honest majority partition': ['Algorand.txt'],
#  'honest majority rely': ['Algorand.txt'],
#  'honest players chooses': ['Algorand.txt'],
#  'honest players signatures': ['Algorand.txt'],
#  'honest probability period': ['Algorand.txt'],
#  'honest proposed value': ['Algorand.txt'],
#  'honest protocol resilient': ['Algorand.txt'],
#  'honest user cert': ['Algorand.txt'],
#  'honest user guaranteed': ['Algorand.txt'],
#  'honest user identi': ['Algorand.txt'],
#  'honest user nishes': ['Algorand.txt'],
#  'honest user received': ['Algorand.txt'],
#  'honest user seen': ['Algorand.txt'],
#  'honest user sees': ['Algorand.txt'],
#  'honest user votes': ['Algorand.txt'],
#  'honest user working': ['Algorand.txt'],
#  'honest users follow': ['Algorand.txt'],
#  'honest users helped': ['Algorand.txt'],
#  'honest users send': ['Algorand.txt'],
#  'honest users soft': ['Algorand.txt'],
#  'honest users started': ['Algorand.txt'],
#  'honest users time': ['Algorand.txt'],
#  'honesty ratio partition': ['Algorand.txt'],
#  'idealized network setting': ['Algorand.txt'],
#  'identi es cid': ['Algorand.txt'],
#  'identities messages retrievable': ['Algorand.txt'],
#  'independently players public': ['Algorand.txt'],
#  'individual timers count': ['Algorand.txt'],
#  'individual timers speed': ['Algorand.txt'],
#  'inductively future periods': ['Algorand.txt'],
#  'input beginning protocol': ['Algorand.txt'],
#  'instantaneously control total': ['Algorand.txt'],
#  'instantaneously permissionless use': ['Algorand.txt'],
#  'interval minutes depending': ['Algorand.txt'],
#  'introduce new steps': ['Algorand.txt'],
#  'introduction concrete network': ['Algorand.txt'],
#  'invariant remains honest': ['Algorand.txt'],
#  'jing chen sergey': ['Algorand.txt'],
#  'jing chen silvio': ['Algorand.txt'],
#  'jing sergey silvio': ['Algorand.txt'],
#  'keeps timer clock': ['Algorand.txt'],
#  'keepscounting theusers individualtimers': ['Algorand.txt'],
#  'key pair digital': ['Algorand.txt'],
#  'key pair maliciously': ['Algorand.txt'],
#  'key points desired': ['Algorand.txt'],
#  'keys known player': ['Algorand.txt'],
#  'keys sign votes': ['Algorand.txt'],
#  'known cryptographic tools': ['Algorand.txt'],
#  'known player denote': ['Algorand.txt'],
#  'lead protocol achieves': ['Algorand.txt'],
#  'leader cid honest': ['Algorand.txt'],
#  'leader cid propose': ['Algorand.txt'],
#  'leader cid proposes': ['Algorand.txt'],
#  'leader election users': ['Algorand.txt'],
#  'leader election works': ['Algorand.txt'],
#  'leader honest honest': ['Algorand.txt'],
#  'leader honest probability': ['Algorand.txt'],
#  'leader honest proposed': ['Algorand.txt'],
#  'leader honest protocol': ['Algorand.txt'],
#  'leader leader cid': ['Algorand.txt'],
#  'leader ned follows': ['Algorand.txt'],
#  'leader period cid': ['Algorand.txt'],
#  'leader proposed value': ['Algorand.txt'],
#  'leader proposes block': ['Algorand.txt'],
#  'leader soft vote': ['Algorand.txt'],
#  'ledger arxiv report': ['Algorand.txt'],
#  'ledger based permissionless': ['Algorand.txt'],
#  'let highest period': ['Algorand.txt'],
#  'long network partition': ['Algorand.txt'],
#  'loop conceptual clarity': ['Algorand.txt'],
#  'loop step periods': ['Algorand.txt'],
#  'majority following classic': ['Algorand.txt'],
#  'majority rely participants': ['Algorand.txt'],
#  'make certi ed': ['Algorand.txt'],
#  'make progress partition': ['Algorand.txt'],
#  'making following assumptions': ['Algorand.txt'],
#  'malicious players learns': ['Algorand.txt'],
#  'maliciously generated ones': ['Algorand.txt'],
#  'manuscript fast byzantine': ['Algorand.txt'],
#  'manuscript simplify protocol': ['Algorand.txt'],
#  'means moving period': ['Algorand.txt'],
#  'message attacks enjoy': ['Algorand.txt'],
#  'message delay restored': ['Algorand.txt'],
#  'message delivery messages': ['Algorand.txt'],
#  'message string accepted': ['Algorand.txt'],
#  'messages messages sent': ['Algorand.txt'],
#  'messages network partitioned': ['Algorand.txt'],
#  'messages propagate faster': ['Algorand.txt'],
#  'messages retrievable signatures': ['Algorand.txt'],
#  'messages seen honest': ['Algorand.txt'],
#  'messages sent malicious': ['Algorand.txt'],
#  'messages start step': ['Algorand.txt'],
#  'messagesaredeliveredwithinaboundedworst casedelay agreementisreachedinexpectedconstant': ['Algorand.txt'],
#  'micali algorand arxiv': ['Algorand.txt'],
#  'micali algorand cient': ['Algorand.txt'],
#  'micali democoin publicly': ['Algorand.txt'],
#  'micali salil vadhan': ['Algorand.txt'],
#  'michael rabin veri': ['Algorand.txt'],
#  'minutes depending fast': ['Algorand.txt'],
#  'modeled random oracle': ['Algorand.txt'],
#  'moment rst honest': ['Algorand.txt'],
#  'moment sees cert': ['Algorand.txt'],
#  'moment user starts': ['Algorand.txt'],
#  'moves step period': ['Algorand.txt'],
#  'moving period seeing': ['Algorand.txt'],
#  'necessary user timer': ['Algorand.txt'],
#  'need synchronized synchronized': ['Algorand.txt'],
#  'need users individual': ['Algorand.txt'],
#  'network bounded delay': ['Algorand.txt'],
#  'network given time': ['Algorand.txt'],
#  'network honest users': ['Algorand.txt'],
#  'network partition following': ['Algorand.txt'],
#  'network partition happens': ['Algorand.txt'],
#  'network partition network': ['Algorand.txt'],
#  'network partitioned message': ['Algorand.txt'],
#  'network partitions unknown': ['Algorand.txt'],
#  'network recovers partition': ['Algorand.txt'],
#  'networks algorand ledger': ['Algorand.txt'],
#  'new steps committees': ['Algorand.txt'],
#  'nickolai zeldovich algorand': ['Algorand.txt'],
#  'nish protocol di': ['Algorand.txt'],
#  'nish protocol period': ['Algorand.txt'],
#  'nish protocol value': ['Algorand.txt'],
#  'nishes previous periods': ['Algorand.txt'],
#  'nishes protocol honest': ['Algorand.txt'],
#  'nition cert vote': ['Algorand.txt'],
#  'nition certi ed': ['Algorand.txt'],
#  'nition credential user': ['Algorand.txt'],
#  'nition leader leader': ['Algorand.txt'],
#  'nition potential starting': ['Algorand.txt'],
#  'nition potentially certi': ['Algorand.txt'],
#  'nition soft vote': ['Algorand.txt'],
#  'nition vote user': ['Algorand.txt'],
#  'note adversary turn': ['Algorand.txt'],
#  'note honest users': ['Algorand.txt'],
#  'number malicious players': ['Algorand.txt'],
#  'numbered steps essentially': ['Algorand.txt'],
#  'odd numbered steps': ['Algorand.txt'],
#  'onceallhonestusersstartthesameperiodpwithintime apart wearebackintheno': ['Algorand.txt'],
#  'optimal dependence honesty': ['Algorand.txt'],
#  'optimality honest majority': ['Algorand.txt'],
#  'oracle digital signatures': ['Algorand.txt'],
#  'order make progress': ['Algorand.txt'],
#  'orders di erent': ['Algorand.txt'],
#  'org abs version': ['Algorand.txt'],
#  'output cert votes': ['Algorand.txt'],
#  'pair digital signature': ['Algorand.txt'],
#  'pair maliciously generated': ['Algorand.txt'],
#  'paper describes random': ['Algorand.txt'],
#  'parallelwiththeblockpropagation ectively aftertheblockpropagates': ['Algorand.txt'],
#  'participants synchronized clocks': ['Algorand.txt'],
#  'particular achieves following': ['Algorand.txt'],
#  'particular honest leader': ['Algorand.txt'],
#  'particular leader honest': ['Algorand.txt'],
#  'partition following properties': ['Algorand.txt'],
#  'partition happens timers': ['Algorand.txt'],
#  'partition honest users': ['Algorand.txt'],
#  'partition network recovers': ['Algorand.txt'],
#  'partition resilience asynchronous': ['Algorand.txt'],
#  'partition resilient byzantine': ['Algorand.txt'],
#  'partition resolved bounded': ['Algorand.txt'],
#  'partition resolved halt': ['Algorand.txt'],
#  'partition resolved honest': ['Algorand.txt'],
#  'partition resolved time': ['Algorand.txt'],
#  'partition resolved votes': ['Algorand.txt'],
#  'partition sending votes': ['Algorand.txt'],
#  'partitioned especially adversary': ['Algorand.txt'],
#  'partitioned message propagated': ['Algorand.txt'],
#  'partitioned unknown time': ['Algorand.txt'],
#  'partitions unknown length': ['Algorand.txt'],
#  'perfectly coordinates malicious': ['Algorand.txt'],
#  'period add steps': ['Algorand.txt'],
#  'period aslongasiremainsinthesameperiod clock': ['Algorand.txt'],
#  'period cert voted': ['Algorand.txt'],
#  'period certi ed': ['Algorand.txt'],
#  'period cid cid': ['Algorand.txt'],
#  'period cid sees': ['Algorand.txt'],
#  'period cid sets': ['Algorand.txt'],
#  'period cid user': ['Algorand.txt'],
#  'period exists certi': ['Algorand.txt'],
#  'period happens leader': ['Algorand.txt'],
#  'period honest user': ['Algorand.txt'],
#  'period inductively future': ['Algorand.txt'],
#  'period leader honest': ['Algorand.txt'],
#  'period leader ned': ['Algorand.txt'],
#  'period moves step': ['Algorand.txt'],
#  'period nishes previous': ['Algorand.txt'],
#  'period output time': ['Algorand.txt'],
#  'period rst moment': ['Algorand.txt'],
#  'period seeing votes': ['Algorand.txt'],
#  'period soon honest': ['Algorand.txt'],
#  'period start period': ['Algorand.txt'],
#  'period starting value': ['Algorand.txt'],
#  'period step period': ['Algorand.txt'],
#  'period step votes': ['Algorand.txt'],
#  'period stp st': ['Algorand.txt'],
#  'period time apart': ['Algorand.txt'],
#  'period time time': ['Algorand.txt'],
#  'period time user': ['Algorand.txt'],
#  'period user argmin': ['Algorand.txt'],
#  'period user starts': ['Algorand.txt'],
#  'period value certi': ['Algorand.txt'],
#  'period value voted': ['Algorand.txt'],
#  'periods cid potential': ['Algorand.txt'],
#  'periods resets clock': ['Algorand.txt'],
#  'periodsandatmost time allhonestusers': ['Algorand.txt'],
#  'permissioned permissionless protocol': ['Algorand.txt'],
#  'permissioned xed set': ['Algorand.txt'],
#  'permissionless protocol corresponds': ['Algorand.txt'],
#  'permissionless protocol described': ['Algorand.txt'],
#  'permissionless protocol period': ['Algorand.txt'],
#  'permissionless setting original': ['Algorand.txt'],
#  'permissionless settings permissionless': ['Algorand.txt'],
#  'permissionless use algorand': ['Algorand.txt'],
#  'player denote signature': ['Algorand.txt'],
#  'player holds secret': ['Algorand.txt'],
#  'player replaceability protocol': ['Algorand.txt'],
#  'player replaceable original': ['Algorand.txt'],
#  'players access public': ['Algorand.txt'],
#  'players chooses messages': ['Algorand.txt'],
#  'players communicate propagation': ['Algorand.txt'],
#  'players communicate steps': ['Algorand.txt'],
#  'players public keys': ['Algorand.txt'],
#  'players signatures break': ['Algorand.txt'],
#  'pocketed adversary case': ['Algorand.txt'],
#  'points desired properties': ['Algorand.txt'],
#  'practice interval minutes': ['Algorand.txt'],
#  'present simple byzantine': ['Algorand.txt'],
#  'previous periods resets': ['Algorand.txt'],
#  'primitives shall rely': ['Algorand.txt'],
#  'private input beginning': ['Algorand.txt'],
#  'private value special': ['Algorand.txt'],
#  'privately public keys': ['Algorand.txt'],
#  'probability period reached': ['Algorand.txt'],
#  'produced voting step': ['Algorand.txt'],
#  'producing certi cate': ['Algorand.txt'],
#  'progress partition particular': ['Algorand.txt'],
#  'propagate faster blocks': ['Algorand.txt'],
#  'propagate network given': ['Algorand.txt'],
#  'propagated honest users': ['Algorand.txt'],
#  'propagates sig cert': ['Algorand.txt'],
#  'propagates sig soft': ['Algorand.txt'],
#  'propagating cert votes': ['Algorand.txt'],
#  'propagation network users': ['Algorand.txt'],
#  'properties described introduction': ['Algorand.txt'],
#  'properties given introduction': ['Algorand.txt'],
#  'properties highlighted introduction': ['Algorand.txt'],
#  'properties hold network': ['Algorand.txt'],
#  'properties honest majority': ['Algorand.txt'],
#  'properties protocol communication': ['Algorand.txt'],
#  'property public secret': ['Algorand.txt'],
#  'proposal user following': ['Algorand.txt'],
#  'propose private input': ['Algorand.txt'],
#  'proposed value agreed': ['Algorand.txt'],
#  'proposed value honest': ['Algorand.txt'],
#  'proposed values hashes': ['Algorand.txt'],
#  'proposes block transactions': ['Algorand.txt'],
#  'proposes step honest': ['Algorand.txt'],
#  'protocol achieves desirable': ['Algorand.txt'],
#  'protocol achieves desired': ['Algorand.txt'],
#  'protocol allows users': ['Algorand.txt'],
#  'protocol applies blockchains': ['Algorand.txt'],
#  'protocol corresponds round': ['Algorand.txt'],
#  'protocol described manuscript': ['Algorand.txt'],
#  'protocol guarantees desirable': ['Algorand.txt'],
#  'protocol honest users': ['Algorand.txt'],
#  'protocol idealized network': ['Algorand.txt'],
#  'protocol optimal dependence': ['Algorand.txt'],
#  'protocol period add': ['Algorand.txt'],
#  'protocol period time': ['Algorand.txt'],
#  'protocol player replaceable': ['Algorand.txt'],
#  'protocol refer types': ['Algorand.txt'],
#  'protocol resilient arbitrary': ['Algorand.txt'],
#  'protocol set possible': ['Algorand.txt'],
#  'protocol simple reaches': ['Algorand.txt'],
#  'protocol step loop': ['Algorand.txt'],
#  'protocol time output': ['Algorand.txt'],
#  'protocol traditional byzantine': ['Algorand.txt'],
#  'protocol used implement': ['Algorand.txt'],
#  'protocol works honest': ['Algorand.txt'],
#  'protocol works using': ['Algorand.txt'],
#  'public keys known': ['Algorand.txt'],
#  'public random string': ['Algorand.txt'],
#  'quickly network partitioned': ['Algorand.txt'],
#  'rabin veri able': ['Algorand.txt'],
#  'random functions focs': ['Algorand.txt'],
#  'random functions vrfs': ['Algorand.txt'],
#  'random oracle digital': ['Algorand.txt'],
#  'random string generated': ['Algorand.txt'],
#  'random string selected': ['Algorand.txt'],
#  'reach step starting': ['Algorand.txt'],
#  'reached constant expected': ['Algorand.txt'],
#  'reaches agreement quickly': ['Algorand.txt'],
#  'receive actual block': ['Algorand.txt'],
#  'receive certi cate': ['Algorand.txt'],
#  'received honest users': ['Algorand.txt'],
#  'received valid period': ['Algorand.txt'],
#  'receives votes value': ['Algorand.txt'],
#  'recovers fast partition': ['Algorand.txt'],
#  'refer types messages': ['Algorand.txt'],
#  'rely known cryptographic': ['Algorand.txt'],
#  'rely participants synchronized': ['Algorand.txt'],
#  'remains honest users': ['Algorand.txt'],
#  'replaceability protocol player': ['Algorand.txt'],
#  'replaceable original algorand': ['Algorand.txt'],
#  'report http arxiv': ['Algorand.txt'],
#  'reset shortly partition': ['Algorand.txt'],
#  'resets time starts': ['Algorand.txt'],
#  'resilience asynchronous safety': ['Algorand.txt'],
#  'resilient agreement protocols': ['Algorand.txt'],
#  'resilient arbitrary network': ['Algorand.txt'],
#  'resilient byzantine agreement': ['Algorand.txt'],
#  'resilient protocol optimal': ['Algorand.txt'],
#  'resolved bounded message': ['Algorand.txt'],
#  'resolved honest user': ['Algorand.txt'],
#  'resolved time constant': ['Algorand.txt'],
#  'resolved time honest': ['Algorand.txt'],
#  'resolved votes means': ['Algorand.txt'],
#  'restores bounded delay': ['Algorand.txt'],
#  'retrievable signatures ne': ['Algorand.txt'],
#  'rotem hemo silvio': ['Algorand.txt'],
#  'rst honest user': ['Algorand.txt'],
#  'rst protocol idealized': ['Algorand.txt'],
#  'rst voting step': ['Algorand.txt'],
#  'rule moving period': ['Algorand.txt'],
#  'safe asynchronous networks': ['Algorand.txt'],
#  'salil vadhan michael': ['Algorand.txt'],
#  'say user cert': ['Algorand.txt'],
#  'say user certi': ['Algorand.txt'],
#  'say user soft': ['Algorand.txt'],
#  'say user votes': ['Algorand.txt'],
#  'buttolph emin gu': ['Avalanche.txt'],
#  'daniel laine stephen': ['Avalanche.txt'],
#  'emin gu sirer': ['Avalanche.txt'],
#  'kevin sekniqi daniel': ['Avalanche.txt'],
#  'laine stephen buttolph': ['Avalanche.txt'],
#  'sekniqi daniel laine': ['Avalanche.txt'],
#  'stephen buttolph emin': ['Avalanche.txt'],
#  'post quantum cryptography': ['Avalanche.txt'],
#  'blockchain ned vm': ['Avalanche.txt'],
#  'codenamed avalanche borealis': ['Avalanche.txt'],
#  'di er materially': ['Avalanche.txt'],
#  'di erent execution': ['Avalanche.txt'],
#  'dns seed nodes': ['Avalanche.txt'],
#  'erent execution environment': ['Avalanche.txt'],
#  'latency high throughput': ['Avalanche.txt'],
#  'longest chain protocols': ['Avalanche.txt'],
#  'low latency high': ['Avalanche.txt'],
#  'network state discovery': ['Avalanche.txt'],
#  'number identi es': ['Avalanche.txt'],
#  'provide security guarantees': ['Avalanche.txt'],
#  'sybil control mechanisms': ['Avalanche.txt'],
#  'ability contribute valid': ['Avalanche.txt'],
#  'ability directly update': ['Avalanche.txt'],
#  'ability scale incurring': ['Avalanche.txt'],
#  'ability validate continuous': ['Avalanche.txt'],
#  'able execute parallel': ['Avalanche.txt'],
#  'able prune old': ['Avalanche.txt'],
#  'able support global': ['Avalanche.txt'],
#  'able support trustless': ['Avalanche.txt'],
#  'able vote changes': ['Avalanche.txt'],
#  'abstract thispaperprovidesanarchitecturaloverviewofthe rstreleaseoftheavalancheplatform': ['Avalanche.txt'],
#  'abundantly owned large': ['Avalanche.txt'],
#  'acceptablevaluesfor systemparametersis criticalfordecentral': ['Avalanche.txt'],
#  'accepted block dag': ['Avalanche.txt'],
#  'accepted correct node': ['Avalanche.txt'],
#  'accepted correct state': ['Avalanche.txt'],
#  'accepted frontier chain': ['Avalanche.txt'],
#  'accepted frontier set': ['Avalanche.txt'],
#  'accepted funds locked': ['Avalanche.txt'],
#  'accepted majority seed': ['Avalanche.txt'],
#  'accepted stake reverted': ['Avalanche.txt'],
#  'accepted state transitions': ['Avalanche.txt'],
#  'access dozens patents': ['Avalanche.txt'],
#  'access state single': ['Avalanche.txt'],
#  'accessible open note': ['Avalanche.txt'],
#  'accompanying token dynamics': ['Avalanche.txt'],
#  'accrue ongoing costs': ['Avalanche.txt'],
#  'accruing strong reward': ['Avalanche.txt'],
#  'accurate actual results': ['Avalanche.txt'],
#  'achieve agreement lie': ['Avalanche.txt'],
#  'achieve high security': ['Avalanche.txt'],
#  'achieve higher performance': ['Avalanche.txt'],
#  'achieve low latency': ['Avalanche.txt'],
#  'achieved assuming higher': ['Avalanche.txt'],
#  'achieved staking order': ['Avalanche.txt'],
#  'act decentralized reserve': ['Avalanche.txt'],
#  'active decisions performed': ['Avalanche.txt'],
#  'active participants mechanism': ['Avalanche.txt'],
#  'active state current': ['Avalanche.txt'],
#  'actors exchanges clients': ['Avalanche.txt'],
#  'actual performance results': ['Avalanche.txt'],
#  'actual results future': ['Avalanche.txt'],
#  'adaptive adversary point': ['Avalanche.txt'],
#  'adaptive unlike voting': ['Avalanche.txt'],
#  'additional features vm': ['Avalanche.txt'],
#  'adoption platform types': ['Avalanche.txt'],
#  'advances development quantum': ['Avalanche.txt'],
#  'adversarial sybil attack': ['Avalanche.txt'],
#  'adversaries avalanche paper': ['Avalanche.txt'],
#  'adversary access state': ['Avalanche.txt'],
#  'adversary known round': ['Avalanche.txt'],
#  'adversary limited statistical': ['Avalanche.txt'],
#  'adversary point point': ['Avalanche.txt'],
#  'adversary purely theoretical': ['Avalanche.txt'],
#  'adversary small highly': ['Avalanche.txt'],
#  'aforementionedmetricsareatthebase layer layer': ['Avalanche.txt'],
#  'agivenvm whencreatingablockchain onespeci': ['Avalanche.txt'],
#  'agree precise membership': ['Avalanche.txt'],
#  'agree separate processing': ['Avalanche.txt'],
#  'aim avalanche provide': ['Avalanche.txt'],
#  'ake avalanche novel': ['Avalanche.txt'],
#  'algorithmic load state': ['Avalanche.txt'],
#  'algorithmic requirements avax': ['Avalanche.txt'],
#  'algorithms concern quantum': ['Avalanche.txt'],
#  'allofwhicharein uencedbygovernableparameters stakingrewardsaresetbyon': ['Avalanche.txt'],
#  'allow token holders': ['Avalanche.txt'],
#  'allow unlimited changes': ['Avalanche.txt'],
#  'allowed decided enforced': ['Avalanche.txt'],
#  'allowing node operator': ['Avalanche.txt'],
#  'allowing thousands transactions': ['Avalanche.txt'],
#  'allowing users safely': ['Avalanche.txt'],
#  'allows node discover': ['Avalanche.txt'],
#  'anchor set seed': ['Avalanche.txt'],
#  'anchors comprise set': ['Avalanche.txt'],
#  'anchors correct example': ['Avalanche.txt'],
#  'anchors dictate node': ['Avalanche.txt'],
#  'anchors ned accepted': ['Avalanche.txt'],
#  'anchors network state': ['Avalanche.txt'],
#  'anchors networked peers': ['Avalanche.txt'],
#  'anchors node queries': ['Avalanche.txt'],
#  'andairdrops allofwhicharein uencedbygovernableparameters': ['Avalanche.txt'],
#  'andreduceload therearevarioustypesofshardingmechanisms innetworksharding': ['Avalanche.txt'],
#  'anodethatwantstoparticipateissuesaspecialstake transaction tothevalidatorchain': ['Avalanche.txt'],
#  'anticipate setting minimum': ['Avalanche.txt'],
#  'apis exposed blockchain': ['Avalanche.txt'],
#  'application speci blockchains': ['Avalanche.txt'],
#  'appropriate know access': ['Avalanche.txt'],
#  'approximations network state': ['Avalanche.txt'],
#  'arbitrarily blockchains run': ['Avalanche.txt'],
#  'arbitrarily blockchains validator': ['Avalanche.txt'],
#  'arbitrarily complex digital': ['Avalanche.txt'],
#  'arbitrarily subnets order': ['Avalanche.txt'],
#  'arbitrarily subnets subnet': ['Avalanche.txt'],
#  'arbitrary aspects instead': ['Avalanche.txt'],
#  'architectural model governance': ['Avalanche.txt'],
#  'architectural model platform': ['Avalanche.txt'],
#  'architectural overview avalanche': ['Avalanche.txt'],
#  'architectural overview platform': ['Avalanche.txt'],
#  'archival light archival': ['Avalanche.txt'],
#  'arealsosubjecttogovernance ise ectivelyatuplewhichde': ['Avalanche.txt'],
#  'argument probability success': ['Avalanche.txt'],
#  'arithmetic improved type': ['Avalanche.txt'],
#  'asdiscussedlater thespeci edstakingduration': ['Avalanche.txt'],
#  'asset directly avalanche': ['Avalanche.txt'],
#  'asset loss staking': ['Avalanche.txt'],
#  'assets base avax': ['Avalanche.txt'],
#  'assets custom rules': ['Avalanche.txt'],
#  'associatedwitheachgovernableparameter timeandrange onceaparameterischangedusingagovernance': ['Avalanche.txt'],
#  'assume kind heavy': ['Avalanche.txt'],
#  'assuming higher bandwidth': ['Avalanche.txt'],
#  'assumption threshold number': ['Avalanche.txt'],
#  'assumption violated possible': ['Avalanche.txt'],
#  'asubnetwork orsubnet isadynamicsetofvalidatorsworkingtogethertoachieveconsensus': ['Avalanche.txt'],
#  'aswellasthereward asdiscussedlater thespeci': ['Avalanche.txt'],
#  'asynchronously safe snow': ['Avalanche.txt'],
#  'atomic swap subnets': ['Avalanche.txt'],
#  'atomic swaps besidesprovidingthecoresecurityofthesystem': ['Avalanche.txt'],
#  'atomic swaps natively': ['Avalanche.txt'],
#  'attaching set seed': ['Avalanche.txt'],
#  'attack directly proportional': ['Avalanche.txt'],
#  'attack node cheaply': ['Avalanche.txt'],
#  'attack pow operations': ['Avalanche.txt'],
#  'attacker certain threshold': ['Avalanche.txt'],
#  'attackers fail completely': ['Avalanche.txt'],
#  'attacks di cult': ['Avalanche.txt'],
#  'attempts scale large': ['Avalanche.txt'],
#  'attheircore allofthesemechanismsserveanidenticalfunction theyrequirethateachparticipanthave': ['Avalanche.txt'],
#  'attributed large holders': ['Avalanche.txt'],
#  'available avalanche staking': ['Avalanche.txt'],
#  'available mainnet launch': ['Avalanche.txt'],
#  'available platform participants': ['Avalanche.txt'],
#  'avalabs org papers': ['Avalanche.txt'],
#  'avalanche able execute': ['Avalanche.txt'],
#  'avalanche allow unlimited': ['Avalanche.txt'],
#  'avalanche borealis details': ['Avalanche.txt'],
#  'avalanche borealis native': ['Avalanche.txt'],
#  'avalanche borealis rst': ['Avalanche.txt'],
#  'avalanche combine best': ['Avalanche.txt'],
#  'avalanche designed massively': ['Avalanche.txt'],
#  'avalanche designed provide': ['Avalanche.txt'],
#  'avalanche designed robust': ['Avalanche.txt'],
#  'avalanche employs egalitarian': ['Avalanche.txt'],
#  'avalanche enable atomic': ['Avalanche.txt'],
#  'avalanche enables functionality': ['Avalanche.txt'],
#  'avalanche face natural': ['Avalanche.txt'],
#  'avalanche goals principles': ['Avalanche.txt'],
#  'avalanche high performance': ['Avalanche.txt'],
#  'avalanche innovates stack': ['Avalanche.txt'],
#  'avalanche network enables': ['Avalanche.txt'],
#  'avalanche network model': ['Avalanche.txt'],
#  'avalanche network simply': ['Avalanche.txt'],
#  'avalanche notation rede': ['Avalanche.txt'],
#  'avalanche novel metastable': ['Avalanche.txt'],
#  'avalanche paper provides': ['Avalanche.txt'],
#  'avalanche peers attaching': ['Avalanche.txt'],
#  'avalanche platform able': ['Avalanche.txt'],
#  'avalanche platform begins': ['Avalanche.txt'],
#  'avalanche platform key': ['Avalanche.txt'],
#  'avalanche platform services': ['Avalanche.txt'],
#  'avalanche platform sybil': ['Avalanche.txt'],
#  'avalanche possesses following': ['Avalanche.txt'],
#  'avalanche projected performance': ['Avalanche.txt'],
#  'avalanche provide security': ['Avalanche.txt'],
#  'avalanche provide unifying': ['Avalanche.txt'],
#  'avalanche provides strong': ['Avalanche.txt'],
#  'avalanche staking rewards': ['Avalanche.txt'],
#  'avalanche support di': ['Avalanche.txt'],
#  'avalanche supports high': ['Avalanche.txt'],
#  'avalanche supports light': ['Avalanche.txt'],
#  'avalanche supports standard': ['Avalanche.txt'],
#  'avalanche token paper': ['Avalanche.txt'],
#  'avalanche undertakes obligation': ['Avalanche.txt'],
#  'avalanche use consensus': ['Avalanche.txt'],
#  'avax capped supply': ['Avalanche.txt'],
#  'avax choose pos': ['Avalanche.txt'],
#  'avax designed react': ['Avalanche.txt'],
#  'avax eventually capped': ['Avalanche.txt'],
#  'avax family consensus': ['Avalanche.txt'],
#  'avax highly inclusive': ['Avalanche.txt'],
#  'avax lives traded': ['Avalanche.txt'],
#  'avax make usage': ['Avalanche.txt'],
#  'avax monetary policy': ['Avalanche.txt'],
#  'avax native token': ['Avalanche.txt'],
#  'avax nodes need': ['Avalanche.txt'],
#  'avax powerful easy': ['Avalanche.txt'],
#  'avax provides chain': ['Avalanche.txt'],
#  'avax provides direct': ['Avalanche.txt'],
#  'avax taken directly': ['Avalanche.txt'],
#  'avax used security': ['Avalanche.txt'],
#  'avax value nes': ['Avalanche.txt'],
#  'avaxsubnet thestakingsubnet andthesmartcontractsubnet': ['Avalanche.txt'],
#  'aworkableprocessfor ndingglobally acceptablevaluesfor': ['Avalanche.txt'],
#  'ba ea dc': ['Avalanche.txt'],
#  'background distributed payments': ['Avalanche.txt'],
#  'bake rate minting': ['Avalanche.txt'],
#  'balance incentives users': ['Avalanche.txt'],
#  'bank levers available': ['Avalanche.txt'],
#  'barrieragainstmisbehaviorbythatparticipant alloftheminvolveaformofstake whetheritisintheform': ['Avalanche.txt'],
#  'base avax used': ['Avalanche.txt'],
#  'based consensus protocols': ['Avalanche.txt'],
#  'based signatures consensus': ['Avalanche.txt'],
#  'based smart contracts': ['Avalanche.txt'],
#  'based staking staking': ['Avalanche.txt'],
#  'based systems snow': ['Avalanche.txt'],
#  'basis economic cost': ['Avalanche.txt'],
#  'bear acquire voice': ['Avalanche.txt'],
#  'begins core component': ['Avalanche.txt'],
#  'behavior blockchain ned': ['Avalanche.txt'],
#  'behavior example subnets': ['Avalanche.txt'],
#  'belong snow family': ['Avalanche.txt'],
#  'beni cial compliance': ['Avalanche.txt'],
#  'best class decentralization': ['Avalanche.txt'],
#  'best properties classical': ['Avalanche.txt'],
#  'big bigger phenomenon': ['Avalanche.txt'],
#  'big miners enjoy': ['Avalanche.txt'],
#  'bigger phenomenon big': ['Avalanche.txt'],
#  'bigger validator nodes': ['Avalanche.txt'],
#  'bitcoin ability contribute': ['Avalanche.txt'],
#  ...}

# %%
# Count occurence of each word
dict_tri_count = {}

for key, values in dict_tri_rev.items():
    dict_tri_count[key] = len(values)

# Sort by occurence
dict_tri_count = dict(sorted(dict_tri_count.items(), key=lambda item: item[1], reverse=True))
dict_tri_count
# Out:
# {'anti money laundering': 4,
#  'https github com': 4,
#  'cid cid cid': 3,
#  'publicly veri able': 3,
#  'bitcoin peer peer': 3,
#  'ethereum virtual machine': 3,
#  'en wikipedia org': 3,
#  'block header block': 3,
#  'eth usd price': 3,
#  'wikipedia org wiki': 3,
#  'bitcoin org bitcoin': 3,
#  'able random functions': 2,
#  'arxiv org abs': 2,
#  'public secret key': 2,
#  'veri able random': 2,
#  'cryptology eprint archive': 2,
#  'eprint archive report': 2,
#  'forward looking statements': 2,
#  'computational resources required': 2,
#  'deploy smart contracts': 2,
#  'based trading volume': 2,
#  'https en wikipedia': 2,
#  'hash hash hash': 2,
#  'proof work block': 2,
#  'allowing willing parties': 2,
#  'based cryptographic proof': 2,
#  'block header transactions': 2,
#  'computer communications security': 2,
#  'computer science pages': 2,
#  'cryptographic proof instead': 2,
#  'directly need trusted': 2,
#  'electronic payment based': 2,
#  'ieee computer society': 2,
#  'able secret sharing': 2,
#  'long range attacks': 2,
#  'advances cryptology crypto': 2,
#  'based blockchain protocols': 2,
#  'https medium com': 2,
#  'https www coindesk': 2,
#  'eips ethereum org': 2,
#  'ethereum org eips': 2,
#  'https eips ethereum': 2,
#  'blog ethereum org': 2,
#  'https ssrn com': 2,
#  'play key role': 2,
#  'ssrn com abstract': 2,
#  'chief operating officer': 2,
#  'allows users pay': 2,
#  'attacks consensus based': 2,
#  'attacks denial service': 2,
#  'attacks smurfing spoofing': 2,
#  'attacks sybil attacks': 2,
#  'based attacks sybil': 2,
#  'algorithm public key': 2,
#  'consensus mechanism proof': 2,
#  'high transaction fees': 2,
#  'delegated proof stake': 2,
#  'certi ed value': 1,
#  'votes value cid': 1,
#  'soft votes value': 1,
#  'ed value period': 1,
#  'potentially certi ed': 1,
#  'value cid period': 1,
#  'honest users cert': 1,
#  'honest users period': 1,
#  'sees soft votes': 1,
#  'user following clock': 1,
#  'certi ed period': 1,
#  'honest users nish': 1,
#  'period honest users': 1,
#  'period leader cid': 1,
#  'propagates period credential': 1,
#  'proposes propagates period': 1,
#  'received votes period': 1,
#  'received votes value': 1,
#  'step user following': 1,
#  'time honest users': 1,
#  'users start period': 1,
#  'votes value period': 1,
#  'honest users start': 1,
#  'honest users vote': 1,
#  'identi es leader': 1,
#  'leader cid period': 1,
#  'period unique potential': 1,
#  'potential starting value': 1,
#  'soft vote step': 1,
#  'soft votes time': 1,
#  'starting value period': 1,
#  'step honest users': 1,
#  'time time apart': 1,
#  'unique potential starting': 1,
#  'users try agree': 1,
#  'value period signature': 1,
#  'value period value': 1,
#  'vote value period': 1,
#  'votes honest users': 1,
#  'agreement protocol leader': 1,
#  'agreement reached constant': 1,
#  'byzantine agreement protocol': 1,
#  'case honest users': 1,
#  'cert vote value': 1,
#  'cert voted step': 1,
#  'cert votes malicious': 1,
#  'cert votes value': 1,
#  'certi ed potentially': 1,
#  'cid cert votes': 1,
#  'cid honest honest': 1,
#  'cid period soft': 1,
#  'communication setting players': 1,
#  'di erent outputs': 1,
#  'ed potentially certi': 1,
#  'es leader cid': 1,
#  'essentially copies step': 1,
#  'fast recovery network': 1,
#  'finishing step user': 1,
#  'gorbunov silvio micali': 1,
#  'helped propagating soft': 1,
#  'honest honest users': 1,
#  'honest users end': 1,
#  'honest users partition': 1,
#  'honest users receive': 1,
#  'honest users voted': 1,
#  'http arxiv org': 1,
#  'leader cid malicious': 1,
#  'messages sent honest': 1,
#  'micali georgios vlachos': 1,
#  'network setting communication': 1,
#  'original algorand protocol': 1,
#  'period finishing step': 1,
#  'period propagates sig': 1,
#  'period receive votes': 1,
#  'period second finishing': 1,
#  'period soft votes': 1,
#  'period value cert': 1,
#  'propagating soft votes': 1,
#  'protocol communication setting': 1,
#  'protocol di erent': 1,
#  'protocol leader election': 1,
#  'recovery network partition': 1,
#  'second finishing step': 1,
#  'secret key pair': 1,
#  'seen votes period': 1,
#  'sees votes period': 1,
#  'sergey gorbunov silvio': 1,
#  'setting players communicate': 1,
#  'shortly partition resolved': 1,
#  'silvio micali algorand': 1,
#  'silvio micali georgios': 1,
#  'soft votes honest': 1,
#  'soft votes leader': 1,
#  'start period time': 1,
#  'step certifying step': 1,
#  'step filtering step': 1,
#  'step honest user': 1,
#  'step period finishing': 1,
#  'step period second': 1,
#  'step value proposal': 1,
#  'steps essentially copies': 1,
#  'try agree value': 1,
#  'user identi es': 1,
#  'user starts period': 1,
#  'user votes value': 1,
#  'users cert vote': 1,
#  'users cert voted': 1,
#  'users end step': 1,
#  'users nish protocol': 1,
#  'users soft vote': 1,
#  'users voted step': 1,
#  'value cert voted': 1,
#  'value certi ed': 1,
#  'value cid cert': 1,
#  'value period propagates': 1,
#  'value period votes': 1,
#  'value potentially certi': 1,
#  'value proposed cid': 1,
#  'votes malicious users': 1,
#  'votes value proposed': 1,
#  'able corrupt users': 1,
#  'able jointly serviced': 1,
#  'able nish period': 1,
#  'able track time': 1,
#  'aby end step': 1,
#  'accepted signature relative': 1,
#  'access public random': 1,
#  'achieves desired properties': 1,
#  'achieves following desirable': 1,
#  'actual block received': 1,
#  'actual blocks protocol': 1,
#  'adaptive chosen message': 1,
#  'adaptively instantaneously control': 1,
#  'add steps numbered': 1,
#  'adding cert votes': 1,
#  'adversary adversary perfectly': 1,
#  'adversary case votes': 1,
#  'adversary complete control': 1,
#  'adversary corrupt users': 1,
#  'adversary forge honest': 1,
#  'adversary fully controls': 1,
#  'adversary make certi': 1,
#  'adversary perfectly coordinates': 1,
#  'adversary permissionless settings': 1,
#  'adversary turn potentially': 1,
#  'aevenifdi erentusersstartperiod hoursapartintime': 1,
#  'aftertheblockpropagates acerti cateisgenerated': 1,
#  'agree block transactions': 1,
#  'agreement leader election': 1,
#  'agreement network bounded': 1,
#  'agreement protocol works': 1,
#  'agreement quickly network': 1,
#  'agreements agreement protocol': 1,
#  'agreements cryptocurrencies sosp': 1,
#  'agreements users try': 1,
#  'algorand arxiv report': 1,
#  'algorand blockchain proposed': 1,
#  'algorand blockchain users': 1,
#  'algorand cient democratic': 1,
#  'algorand ledger based': 1,
#  'algorand protocol adversary': 1,
#  'align communication setting': 1,
#  'allows change set': 1,
#  'allows users soft': 1,
#  'apart invariant remains': 1,
#  'apart wearebackintheno partition': 1,
#  'applies blockchains permissionless': 1,
#  'arbitrarily partitioned unknown': 1,
#  'arbitrary network partitions': 1,
#  'arbitrary partition resilience': 1,
#  'argmin sig set': 1,
#  'arxiv report http': 1,
#  'aslongasiremainsinthesameperiod clock keepscounting': 1,
#  'assumptions manuscript simplify': 1,
#  'assumptions soon relaxed': 1,
#  'asynchronous networks algorand': 1,
#  'asynchronous safety network': 1,
#  'attacks enjoy following': 1,
#  'beginning protocol set': 1,
#  'block transactions rst': 1,
#  'block transactions similarly': 1,
#  'blockchain proposed values': 1,
#  'blockchain users agree': 1,
#  'blocks hashes soft': 1,
#  'blocks propagated parallel': 1,
#  'blocks protocol allows': 1,
#  'bound agreement reached': 1,
#  'bounded delay agreement': 1,
#  'bounded delay honest': 1,
#  'bounded message delay': 1,
#  'break hash function': 1,
#  'brie discuss protocol': 1,
#  'bwhenthenetworkisnotpartitioned anhonestuseralwaysgoesthroughperiodsinorder duringapartition': 1,
#  'byzantine agreement leader': 1,
#  'byzantine agreements cryptocurrencies': 1,
#  'byzantine agreements users': 1,
#  'case votes propagated': 1,
#  'cases honest users': 1,
#  'cate partition honest': 1,
#  'cate produced voting': 1,
#  'cate time partition': 1,
#  'cate voting step': 1,
#  'cert vote moment': 1,
#  'cert vote time': 1,
#  'cert vote user': 1,
#  'cert voted helped': 1,
#  'cert voted nish': 1,
#  'cert voted potentially': 1,
#  'cert voted users': 1,
#  'cert voted value': 1,
#  'cert votes form': 1,
#  'cert votes period': 1,
#  'cert votes sees': 1,
#  'certi cate partition': 1,
#  'certi cate produced': 1,
#  'certi cate time': 1,
#  'certi cate voting': 1,
#  'certi ed adding': 1,
#  'certi ed unique': 1,
#  'certifying step user': 1,
#  'change set users': 1,
#  'changes lead protocol': 1,
#  'chen sergey gorbunov': 1,
#  'chen silvio micali': 1,
#  'chooses messages sent': 1,
#  'chosen message attacks': 1,
#  'cid certi ed': 1,
#  'cid cid start': 1,
#  'cid honest users': 1,
#  'cid leader step': 1,
#  'cid malicious protocol': 1,
#  'cid period user': 1,
#  'cid period voted': 1,
#  'cid period votes': 1,
#  'cid propose private': 1,
#  'cid proposes step': 1,
#  'cid seen votes': 1,
#  'cid sees votes': 1,
#  'cid sets cid': 1,
#  'cid soft votes': 1,
#  'cid start period': 1,
#  'cid user sets': 1,
#  'cient democratic ledger': 1,
#  'clarity loop step': 1,
#  'classic literature byzantine': 1,
#  'clock keepscounting theusers': 1,
#  'clock resets time': 1,
#  'clocks individual timers': 1,
#  'combined step separate': 1,
#  'combining facts period': 1,
#  'committee members use': 1,
#  'committee selection manuscript': 1,
#  'committees committee members': 1,
#  'committees order make': 1,
#  'communicate propagation network': 1,
#  'communicate steps synchronous': 1,
#  'communication setting omitted': 1,
#  'communication setting steps': 1,
#  'compared period honest': 1,
#  'complete control message': 1,
#  'conceptual clarity loop': 1,
#  'concrete network setting': 1,
#  'condition communication setting': 1,
#  'conditions committee selection': 1,
#  'constant expected time': 1,
#  'control message delivery': 1,
#  'coordinates malicious players': 1,
#  'copies step odd': 1,
#  'corresponding conditions committee': 1,
#  'corresponding rule moving': 1,
#  'corrupt users adaptively': 1,
#  'corrupt users dynamically': 1,
#  'corrupt users instantaneously': 1,
#  'corrupted partition sending': 1,
#  'count short xed': 1,
#  'credential period sig': 1,
#  'credential user credential': 1,
#  'cryptocurrency cryptology eprint': 1,
#  'cryptographic primitives shall': 1,
#  'cryptographic self selection': 1,
#  'cryptographic tools hash': 1,
#  'delay agreement reached': 1,
#  'delay honest messages': 1,
#  'delivered honest users': 1,
#  'delivery messages network': 1,
#  'delivery orders di': 1,
#  'democoin publicly veri': 1,
#  'democratic ledger arxiv': 1,
#  'denote signature string': 1,
#  'denoted special symbol': 1,
#  'dependence honesty ratio': 1,
#  'depending fast block': 1,
#  'describes random string': 1,
#  'desirable properties described': 1,
#  'desirable properties honest': 1,
#  'desired properties given': 1,
#  'desired properties protocol': 1,
#  'di erent messages': 1,
#  'di erent users': 1,
#  'digital signature scheme': 1,
#  'digital signatures precisely': 1,
#  'discuss protocol applies': 1,
#  'dynamic adversary permissionless': 1,
#  'dynamically small committees': 1,
#  'ectively aftertheblockpropagates acerti': 1,
#  'ed adding cert': 1,
#  'ed period cert': 1,
#  'ed period honest': 1,
#  'ed period receive': 1,
#  'ed unique value': 1,
#  'ed value adding': 1,
#  'ed value certi': 1,
#  'ed value cid': 1,
#  'election users try': 1,
#  'end step honest': 1,
#  'end step messages': 1,
#  'end step user': 1,
#  'ensure signer identities': 1,
#  'ephemeral keys sign': 1,
#  'erent messages messages': 1,
#  'erent users private': 1,
#  'erentusersstartperiod hoursapartintime itisasifthenetworkhasbeenpartitionedand': 1,
#  'es cid leader': 1,
#  'es leader period': 1,
#  'especially adversary complete': 1,
#  'execution permissionless protocol': 1,
#  'exist values votes': 1,
#  'exist votes honest': 1,
#  'exists certi ed': 1,
#  'expected time particular': 1,
#  'extra time compared': 1,
#  'facts period leader': 1,
#  'fast agreement network': 1,
#  'fast agreement partition': 1,
#  'fast block propagates': 1,
#  'fast byzantine agreement': 1,
#  'fast partition resilient': 1,
#  'fast partition resolved': 1,
#  'filtering step user': 1,
#  'follow leader soft': 1,
#  'following assumptions soon': 1,
#  'following classic literature': 1,
#  'following desirable properties': 1,
#  'following properties hold': 1,
#  'forge honest players': 1,
#  'forhistoricalreferences extensions andevaluationofalgorandledgerwerefertheinterestedreadersto': 1,
#  'form certi cate': 1,
#  'function modeled random': 1,
#  'functions vrfs constructed': 1,
#  'future periods cid': 1,
#  'generalized permissionless setting': 1,
#  'generally certi ed': 1,
#  'generated updated blockchain': 1,
#  'georgios algorand com': 1,
#  'georgios vlachos nickolai': 1,
#  'gilad rotem hemo': 1,
#  'given time bound': 1,
#  'guaranteed votes value': 1,
#  'guarantees desirable properties': 1,
#  'halting condition communication': 1,
#  'halts moment sees': 1,
#  'happens leader cid': 1,
#  'happens timers reset': 1,
#  'hashes blocks propagated': 1,
#  'hashes soft votes': 1,
#  'hashes step seeing': 1,
#  'helped propagating cert': 1,
#  'hemo silvio micali': 1,
#  'highest period honest': 1,
#  'highlighted introduction concrete': 1,
#  'holds secret key': 1,
#  'honest honest user': 1,
#  'honest leader proposes': 1,
#  'honest majority following': 1,
#  'honest majority partition': 1,
#  'honest majority rely': 1,
#  'honest players chooses': 1,
#  'honest players signatures': 1,
#  'honest probability period': 1,
#  'honest proposed value': 1,
#  'honest protocol resilient': 1,
#  'honest user cert': 1,
#  'honest user guaranteed': 1,
#  'honest user identi': 1,
#  'honest user nishes': 1,
#  'honest user received': 1,
#  'honest user seen': 1,
#  'honest user sees': 1,
#  'honest user votes': 1,
#  'honest user working': 1,
#  'honest users follow': 1,
#  'honest users helped': 1,
#  'honest users send': 1,
#  'honest users soft': 1,
#  'honest users started': 1,
#  'honest users time': 1,
#  'honesty ratio partition': 1,
#  'idealized network setting': 1,
#  'identi es cid': 1,
#  'identities messages retrievable': 1,
#  'independently players public': 1,
#  'individual timers count': 1,
#  'individual timers speed': 1,
#  'inductively future periods': 1,
#  'input beginning protocol': 1,
#  'instantaneously control total': 1,
#  'instantaneously permissionless use': 1,
#  'interval minutes depending': 1,
#  'introduce new steps': 1,
#  'introduction concrete network': 1,
#  'invariant remains honest': 1,
#  'jing chen sergey': 1,
#  'jing chen silvio': 1,
#  'jing sergey silvio': 1,
#  'keeps timer clock': 1,
#  'keepscounting theusers individualtimers': 1,
#  'key pair digital': 1,
#  'key pair maliciously': 1,
#  'key points desired': 1,
#  'keys known player': 1,
#  'keys sign votes': 1,
#  'known cryptographic tools': 1,
#  'known player denote': 1,
#  'lead protocol achieves': 1,
#  'leader cid honest': 1,
#  'leader cid propose': 1,
#  'leader cid proposes': 1,
#  'leader election users': 1,
#  'leader election works': 1,
#  'leader honest honest': 1,
#  'leader honest probability': 1,
#  'leader honest proposed': 1,
#  'leader honest protocol': 1,
#  'leader leader cid': 1,
#  'leader ned follows': 1,
#  'leader period cid': 1,
#  'leader proposed value': 1,
#  'leader proposes block': 1,
#  'leader soft vote': 1,
#  'ledger arxiv report': 1,
#  'ledger based permissionless': 1,
#  'let highest period': 1,
#  'long network partition': 1,
#  'loop conceptual clarity': 1,
#  'loop step periods': 1,
#  'majority following classic': 1,
#  'majority rely participants': 1,
#  'make certi ed': 1,
#  'make progress partition': 1,
#  'making following assumptions': 1,
#  'malicious players learns': 1,
#  'maliciously generated ones': 1,
#  'manuscript fast byzantine': 1,
#  'manuscript simplify protocol': 1,
#  'means moving period': 1,
#  'message attacks enjoy': 1,
#  'message delay restored': 1,
#  'message delivery messages': 1,
#  'message string accepted': 1,
#  'messages messages sent': 1,
#  'messages network partitioned': 1,
#  'messages propagate faster': 1,
#  'messages retrievable signatures': 1,
#  'messages seen honest': 1,
#  'messages sent malicious': 1,
#  'messages start step': 1,
#  'messagesaredeliveredwithinaboundedworst casedelay agreementisreachedinexpectedconstant': 1,
#  'micali algorand arxiv': 1,
#  'micali algorand cient': 1,
#  'micali democoin publicly': 1,
#  'micali salil vadhan': 1,
#  'michael rabin veri': 1,
#  'minutes depending fast': 1,
#  'modeled random oracle': 1,
#  'moment rst honest': 1,
#  'moment sees cert': 1,
#  'moment user starts': 1,
#  'moves step period': 1,
#  'moving period seeing': 1,
#  'necessary user timer': 1,
#  'need synchronized synchronized': 1,
#  'need users individual': 1,
#  'network bounded delay': 1,
#  'network given time': 1,
#  'network honest users': 1,
#  'network partition following': 1,
#  'network partition happens': 1,
#  'network partition network': 1,
#  'network partitioned message': 1,
#  'network partitions unknown': 1,
#  'network recovers partition': 1,
#  'networks algorand ledger': 1,
#  'new steps committees': 1,
#  'nickolai zeldovich algorand': 1,
#  'nish protocol di': 1,
#  'nish protocol period': 1,
#  'nish protocol value': 1,
#  'nishes previous periods': 1,
#  'nishes protocol honest': 1,
#  'nition cert vote': 1,
#  'nition certi ed': 1,
#  'nition credential user': 1,
#  'nition leader leader': 1,
#  'nition potential starting': 1,
#  'nition potentially certi': 1,
#  'nition soft vote': 1,
#  'nition vote user': 1,
#  'note adversary turn': 1,
#  'note honest users': 1,
#  'number malicious players': 1,
#  'numbered steps essentially': 1,
#  'odd numbered steps': 1,
#  'onceallhonestusersstartthesameperiodpwithintime apart wearebackintheno': 1,
#  'optimal dependence honesty': 1,
#  'optimality honest majority': 1,
#  'oracle digital signatures': 1,
#  'order make progress': 1,
#  'orders di erent': 1,
#  'org abs version': 1,
#  'output cert votes': 1,
#  'pair digital signature': 1,
#  'pair maliciously generated': 1,
#  'paper describes random': 1,
#  'parallelwiththeblockpropagation ectively aftertheblockpropagates': 1,
#  'participants synchronized clocks': 1,
#  'particular achieves following': 1,
#  'particular honest leader': 1,
#  'particular leader honest': 1,
#  'partition following properties': 1,
#  'partition happens timers': 1,
#  'partition honest users': 1,
#  'partition network recovers': 1,
#  'partition resilience asynchronous': 1,
#  'partition resilient byzantine': 1,
#  'partition resolved bounded': 1,
#  'partition resolved halt': 1,
#  'partition resolved honest': 1,
#  'partition resolved time': 1,
#  'partition resolved votes': 1,
#  'partition sending votes': 1,
#  'partitioned especially adversary': 1,
#  'partitioned message propagated': 1,
#  'partitioned unknown time': 1,
#  'partitions unknown length': 1,
#  'perfectly coordinates malicious': 1,
#  'period add steps': 1,
#  'period aslongasiremainsinthesameperiod clock': 1,
#  'period cert voted': 1,
#  'period certi ed': 1,
#  'period cid cid': 1,
#  'period cid sees': 1,
#  'period cid sets': 1,
#  'period cid user': 1,
#  'period exists certi': 1,
#  'period happens leader': 1,
#  'period honest user': 1,
#  'period inductively future': 1,
#  'period leader honest': 1,
#  'period leader ned': 1,
#  'period moves step': 1,
#  'period nishes previous': 1,
#  'period output time': 1,
#  'period rst moment': 1,
#  'period seeing votes': 1,
#  'period soon honest': 1,
#  'period start period': 1,
#  'period starting value': 1,
#  'period step period': 1,
#  'period step votes': 1,
#  'period stp st': 1,
#  'period time apart': 1,
#  'period time time': 1,
#  'period time user': 1,
#  'period user argmin': 1,
#  'period user starts': 1,
#  'period value certi': 1,
#  'period value voted': 1,
#  'periods cid potential': 1,
#  'periods resets clock': 1,
#  'periodsandatmost time allhonestusers': 1,
#  'permissioned permissionless protocol': 1,
#  'permissioned xed set': 1,
#  'permissionless protocol corresponds': 1,
#  'permissionless protocol described': 1,
#  'permissionless protocol period': 1,
#  'permissionless setting original': 1,
#  'permissionless settings permissionless': 1,
#  'permissionless use algorand': 1,
#  'player denote signature': 1,
#  'player holds secret': 1,
#  'player replaceability protocol': 1,
#  'player replaceable original': 1,
#  'players access public': 1,
#  'players chooses messages': 1,
#  'players communicate propagation': 1,
#  'players communicate steps': 1,
#  'players public keys': 1,
#  'players signatures break': 1,
#  'pocketed adversary case': 1,
#  'points desired properties': 1,
#  'practice interval minutes': 1,
#  'present simple byzantine': 1,
#  'previous periods resets': 1,
#  'primitives shall rely': 1,
#  'private input beginning': 1,
#  'private value special': 1,
#  'privately public keys': 1,
#  'probability period reached': 1,
#  'produced voting step': 1,
#  'producing certi cate': 1,
#  'progress partition particular': 1,
#  'propagate faster blocks': 1,
#  'propagate network given': 1,
#  'propagated honest users': 1,
#  'propagates sig cert': 1,
#  'propagates sig soft': 1,
#  'propagating cert votes': 1,
#  'propagation network users': 1,
#  'properties described introduction': 1,
#  'properties given introduction': 1,
#  'properties highlighted introduction': 1,
#  'properties hold network': 1,
#  'properties honest majority': 1,
#  'properties protocol communication': 1,
#  'property public secret': 1,
#  'proposal user following': 1,
#  'propose private input': 1,
#  'proposed value agreed': 1,
#  'proposed value honest': 1,
#  'proposed values hashes': 1,
#  'proposes block transactions': 1,
#  'proposes step honest': 1,
#  'protocol achieves desirable': 1,
#  'protocol achieves desired': 1,
#  'protocol allows users': 1,
#  'protocol applies blockchains': 1,
#  'protocol corresponds round': 1,
#  'protocol described manuscript': 1,
#  'protocol guarantees desirable': 1,
#  'protocol honest users': 1,
#  'protocol idealized network': 1,
#  'protocol optimal dependence': 1,
#  'protocol period add': 1,
#  'protocol period time': 1,
#  'protocol player replaceable': 1,
#  'protocol refer types': 1,
#  'protocol resilient arbitrary': 1,
#  'protocol set possible': 1,
#  'protocol simple reaches': 1,
#  'protocol step loop': 1,
#  'protocol time output': 1,
#  'protocol traditional byzantine': 1,
#  'protocol used implement': 1,
#  'protocol works honest': 1,
#  'protocol works using': 1,
#  'public keys known': 1,
#  'public random string': 1,
#  'quickly network partitioned': 1,
#  'rabin veri able': 1,
#  'random functions focs': 1,
#  'random functions vrfs': 1,
#  'random oracle digital': 1,
#  'random string generated': 1,
#  'random string selected': 1,
#  'reach step starting': 1,
#  'reached constant expected': 1,
#  'reaches agreement quickly': 1,
#  'receive actual block': 1,
#  'receive certi cate': 1,
#  'received honest users': 1,
#  'received valid period': 1,
#  'receives votes value': 1,
#  'recovers fast partition': 1,
#  'refer types messages': 1,
#  'rely known cryptographic': 1,
#  'rely participants synchronized': 1,
#  'remains honest users': 1,
#  'replaceability protocol player': 1,
#  'replaceable original algorand': 1,
#  'report http arxiv': 1,
#  'reset shortly partition': 1,
#  'resets time starts': 1,
#  'resilience asynchronous safety': 1,
#  'resilient agreement protocols': 1,
#  'resilient arbitrary network': 1,
#  'resilient byzantine agreement': 1,
#  'resilient protocol optimal': 1,
#  'resolved bounded message': 1,
#  'resolved honest user': 1,
#  'resolved time constant': 1,
#  'resolved time honest': 1,
#  'resolved votes means': 1,
#  'restores bounded delay': 1,
#  'retrievable signatures ne': 1,
#  'rotem hemo silvio': 1,
#  'rst honest user': 1,
#  'rst protocol idealized': 1,
#  'rst voting step': 1,
#  'rule moving period': 1,
#  'safe asynchronous networks': 1,
#  'salil vadhan michael': 1,
#  'say user cert': 1,
#  'say user certi': 1,
#  'say user soft': 1,
#  'say user votes': 1,
#  'buttolph emin gu': 1,
#  'daniel laine stephen': 1,
#  'emin gu sirer': 1,
#  'kevin sekniqi daniel': 1,
#  'laine stephen buttolph': 1,
#  'sekniqi daniel laine': 1,
#  'stephen buttolph emin': 1,
#  'post quantum cryptography': 1,
#  'blockchain ned vm': 1,
#  'codenamed avalanche borealis': 1,
#  'di er materially': 1,
#  'di erent execution': 1,
#  'dns seed nodes': 1,
#  'erent execution environment': 1,
#  'latency high throughput': 1,
#  'longest chain protocols': 1,
#  'low latency high': 1,
#  'network state discovery': 1,
#  'number identi es': 1,
#  'provide security guarantees': 1,
#  'sybil control mechanisms': 1,
#  'ability contribute valid': 1,
#  'ability directly update': 1,
#  'ability scale incurring': 1,
#  'ability validate continuous': 1,
#  'able execute parallel': 1,
#  'able prune old': 1,
#  'able support global': 1,
#  'able support trustless': 1,
#  'able vote changes': 1,
#  'abstract thispaperprovidesanarchitecturaloverviewofthe rstreleaseoftheavalancheplatform': 1,
#  'abundantly owned large': 1,
#  'acceptablevaluesfor systemparametersis criticalfordecentral': 1,
#  'accepted block dag': 1,
#  'accepted correct node': 1,
#  'accepted correct state': 1,
#  'accepted frontier chain': 1,
#  'accepted frontier set': 1,
#  'accepted funds locked': 1,
#  'accepted majority seed': 1,
#  'accepted stake reverted': 1,
#  'accepted state transitions': 1,
#  'access dozens patents': 1,
#  'access state single': 1,
#  'accessible open note': 1,
#  'accompanying token dynamics': 1,
#  'accrue ongoing costs': 1,
#  'accruing strong reward': 1,
#  'accurate actual results': 1,
#  'achieve agreement lie': 1,
#  'achieve high security': 1,
#  'achieve higher performance': 1,
#  'achieve low latency': 1,
#  'achieved assuming higher': 1,
#  'achieved staking order': 1,
#  'act decentralized reserve': 1,
#  'active decisions performed': 1,
#  'active participants mechanism': 1,
#  'active state current': 1,
#  'actors exchanges clients': 1,
#  'actual performance results': 1,
#  'actual results future': 1,
#  'adaptive adversary point': 1,
#  'adaptive unlike voting': 1,
#  'additional features vm': 1,
#  'adoption platform types': 1,
#  'advances development quantum': 1,
#  'adversarial sybil attack': 1,
#  'adversaries avalanche paper': 1,
#  'adversary access state': 1,
#  'adversary known round': 1,
#  'adversary limited statistical': 1,
#  'adversary point point': 1,
#  'adversary purely theoretical': 1,
#  'adversary small highly': 1,
#  'aforementionedmetricsareatthebase layer layer': 1,
#  'agivenvm whencreatingablockchain onespeci': 1,
#  'agree precise membership': 1,
#  'agree separate processing': 1,
#  'aim avalanche provide': 1,
#  'ake avalanche novel': 1,
#  'algorithmic load state': 1,
#  'algorithmic requirements avax': 1,
#  'algorithms concern quantum': 1,
#  'allofwhicharein uencedbygovernableparameters stakingrewardsaresetbyon': 1,
#  'allow token holders': 1,
#  'allow unlimited changes': 1,
#  'allowed decided enforced': 1,
#  'allowing node operator': 1,
#  'allowing thousands transactions': 1,
#  'allowing users safely': 1,
#  'allows node discover': 1,
#  'anchor set seed': 1,
#  'anchors comprise set': 1,
#  'anchors correct example': 1,
#  'anchors dictate node': 1,
#  'anchors ned accepted': 1,
#  'anchors network state': 1,
#  'anchors networked peers': 1,
#  'anchors node queries': 1,
#  'andairdrops allofwhicharein uencedbygovernableparameters': 1,
#  'andreduceload therearevarioustypesofshardingmechanisms innetworksharding': 1,
#  'anodethatwantstoparticipateissuesaspecialstake transaction tothevalidatorchain': 1,
#  'anticipate setting minimum': 1,
#  'apis exposed blockchain': 1,
#  'application speci blockchains': 1,
#  'appropriate know access': 1,
#  'approximations network state': 1,
#  'arbitrarily blockchains run': 1,
#  'arbitrarily blockchains validator': 1,
#  'arbitrarily complex digital': 1,
#  'arbitrarily subnets order': 1,
#  'arbitrarily subnets subnet': 1,
#  'arbitrary aspects instead': 1,
#  'architectural model governance': 1,
#  'architectural model platform': 1,
#  'architectural overview avalanche': 1,
#  'architectural overview platform': 1,
#  'archival light archival': 1,
#  'arealsosubjecttogovernance ise ectivelyatuplewhichde': 1,
#  'argument probability success': 1,
#  'arithmetic improved type': 1,
#  'asdiscussedlater thespeci edstakingduration': 1,
#  'asset directly avalanche': 1,
#  'asset loss staking': 1,
#  'assets base avax': 1,
#  'assets custom rules': 1,
#  'associatedwitheachgovernableparameter timeandrange onceaparameterischangedusingagovernance': 1,
#  'assume kind heavy': 1,
#  'assuming higher bandwidth': 1,
#  'assumption threshold number': 1,
#  'assumption violated possible': 1,
#  'asubnetwork orsubnet isadynamicsetofvalidatorsworkingtogethertoachieveconsensus': 1,
#  'aswellasthereward asdiscussedlater thespeci': 1,
#  'asynchronously safe snow': 1,
#  'atomic swap subnets': 1,
#  'atomic swaps besidesprovidingthecoresecurityofthesystem': 1,
#  'atomic swaps natively': 1,
#  'attaching set seed': 1,
#  'attack directly proportional': 1,
#  'attack node cheaply': 1,
#  'attack pow operations': 1,
#  'attacker certain threshold': 1,
#  'attackers fail completely': 1,
#  'attacks di cult': 1,
#  'attempts scale large': 1,
#  'attheircore allofthesemechanismsserveanidenticalfunction theyrequirethateachparticipanthave': 1,
#  'attributed large holders': 1,
#  'available avalanche staking': 1,
#  'available mainnet launch': 1,
#  'available platform participants': 1,
#  'avalabs org papers': 1,
#  'avalanche able execute': 1,
#  'avalanche allow unlimited': 1,
#  'avalanche borealis details': 1,
#  'avalanche borealis native': 1,
#  'avalanche borealis rst': 1,
#  'avalanche combine best': 1,
#  'avalanche designed massively': 1,
#  'avalanche designed provide': 1,
#  'avalanche designed robust': 1,
#  'avalanche employs egalitarian': 1,
#  'avalanche enable atomic': 1,
#  'avalanche enables functionality': 1,
#  'avalanche face natural': 1,
#  'avalanche goals principles': 1,
#  'avalanche high performance': 1,
#  'avalanche innovates stack': 1,
#  'avalanche network enables': 1,
#  'avalanche network model': 1,
#  'avalanche network simply': 1,
#  'avalanche notation rede': 1,
#  'avalanche novel metastable': 1,
#  'avalanche paper provides': 1,
#  'avalanche peers attaching': 1,
#  'avalanche platform able': 1,
#  'avalanche platform begins': 1,
#  'avalanche platform key': 1,
#  'avalanche platform services': 1,
#  'avalanche platform sybil': 1,
#  'avalanche possesses following': 1,
#  'avalanche projected performance': 1,
#  'avalanche provide security': 1,
#  'avalanche provide unifying': 1,
#  'avalanche provides strong': 1,
#  'avalanche staking rewards': 1,
#  'avalanche support di': 1,
#  'avalanche supports high': 1,
#  'avalanche supports light': 1,
#  'avalanche supports standard': 1,
#  'avalanche token paper': 1,
#  'avalanche undertakes obligation': 1,
#  'avalanche use consensus': 1,
#  'avax capped supply': 1,
#  'avax choose pos': 1,
#  'avax designed react': 1,
#  'avax eventually capped': 1,
#  'avax family consensus': 1,
#  'avax highly inclusive': 1,
#  'avax lives traded': 1,
#  'avax make usage': 1,
#  'avax monetary policy': 1,
#  'avax native token': 1,
#  'avax nodes need': 1,
#  'avax powerful easy': 1,
#  'avax provides chain': 1,
#  'avax provides direct': 1,
#  'avax taken directly': 1,
#  'avax used security': 1,
#  'avax value nes': 1,
#  'avaxsubnet thestakingsubnet andthesmartcontractsubnet': 1,
#  'aworkableprocessfor ndingglobally acceptablevaluesfor': 1,
#  'ba ea dc': 1,
#  'background distributed payments': 1,
#  'bake rate minting': 1,
#  'balance incentives users': 1,
#  'bank levers available': 1,
#  'barrieragainstmisbehaviorbythatparticipant alloftheminvolveaformofstake whetheritisintheform': 1,
#  'base avax used': 1,
#  'based consensus protocols': 1,
#  'based signatures consensus': 1,
#  'based smart contracts': 1,
#  'based staking staking': 1,
#  'based systems snow': 1,
#  'basis economic cost': 1,
#  'bear acquire voice': 1,
#  'begins core component': 1,
#  'behavior blockchain ned': 1,
#  'behavior example subnets': 1,
#  'belong snow family': 1,
#  'beni cial compliance': 1,
#  'best class decentralization': 1,
#  'best properties classical': 1,
#  'big bigger phenomenon': 1,
#  'big miners enjoy': 1,
#  'bigger phenomenon big': 1,
#  'bigger validator nodes': 1,
#  'bitcoin ability contribute': 1,
#  ...}

# %% [markdown]
# ### Actual result
# The previous column shows top 10 occurence in trigram model among 20 whitepapers
