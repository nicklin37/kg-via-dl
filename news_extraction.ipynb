# %%
from bs4 import BeautifulSoup
import requests

# %%
from urllib.request import urlopen
import json
import sys
import re

# %%
url = 'https://finance.yahoo.com/news/teva-sell-record-5-billion-152310124.html'
response = requests.get(url)
response.status_code, response.reason
# Out:
# (404, 'Not Found')

# %%
soup = BeautifulSoup(response.text)

# %%
news = soup.find('div', attrs={'class': 'caas-body'}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b75dba6b1903> in <module>
# ----> 1 news = soup.find('div', attrs={'class': 'caas-body'}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# API Key: 0c4ee1e3efac4634a545e2080365b288

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='0c4ee1e3efac4634a545e2080365b288')

# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='bitcoin',
                                          category='business',
                                          language='en')

# /v2/everything
all_articles = newsapi.get_everything(q='bitcoin',
                                      from_param='2022-01-01',
                                      to='2022-01-15',
                                      language='en',
                                      sort_by='relevancy',
                                      page=2)

# /v2/top-headlines/sources
sources = newsapi.get_sources()

# %%
top_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 16,
#  'articles': [{'source': {'id': None, 'name': 'Bitcoin.com'},
#    'author': None,
#    'title': "Vitalik Buterin to Use $100 Million From Crypto Relief's SHIB Funds to Accelerate Covid Relief Efforts – Featured Bitcoin News - Bitcoin News",
#    'description': "Ethereum co-founder Vitalik Buterin has unveiled how he will use $100 million in cryptocurrency from India's Covid Crypto Relief Fund.",
#    'url': 'https://news.bitcoin.com/vitalik-buterin-100-million-crypto-reliefs-shib-funds-accelerate-covid-relief-efforts/',
#    'urlToImage': 'https://static.news.bitcoin.com/wp-content/uploads/2022/01/vitalik-1.jpg',
#    'publishedAt': '2022-01-30T03:00:08Z',
#    'content': 'Ethereum co-founder Vitalik Buterin has unveiled how he will use $100 million in cryptocurrency from India’s Covid Crypto Relief Fund (Cryptorelief) to accelerate relief efforts and “bring great bene… [+2881 chars]'},
#   {'source': {'id': None, 'name': 'Bitcoin.com'},
# ...

# %%
news_url = top_headlines['articles'][0]['url']

# %%
top_headlines['articles'][0]['content'][:180]
# Out:
# 'Ethereum co-founder Vitalik Buterin has unveiled how he will use $100 million in cryptocurrency from India’s Covid Crypto Relief Fund (Cryptorelief) to accelerate relief efforts an'

# %%
news_url
# Out:
# 'https://news.bitcoin.com/vitalik-buterin-100-million-crypto-reliefs-shib-funds-accelerate-covid-relief-efforts/'

# %%
response = requests.get(news_url)

# %%
news_text = response.text

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html >
#
# <!--[if IE 8]>
# <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>
# <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-US"> <!--<![endif]-->
# <head>
# <style>
#         #big-grid-reveal {
#             visibility: hidden;
#             opacity: 1;
#             transition: visibility 0s linear 0s, opacity 300ms;
#         }
#     </style>
# <title>Vitalik Buterin to Use $100 Million From Crypto Relief's SHIB Funds to Accelerate Covid Relief Efforts – Featured Bitcoin News</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://news.bitcoin.com/xmlrpc.php" rel="pingback"/>
# <style id="" media="all">@font-face {
#   font-family: 'Inconsolata';
#   font-style: normal;
#   font-weight: 400;
#   font-stretch: normal;
# ...
