# %%
import pandas as pd
import tweepy
import re

from datetime import date
from datetime import datetime
from twarc.client2 import Twarc2

# %%
from twarc import expansions

# %%
import time

# %%
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Date:{ith_tweet[2]}")
    print(f"Time:{ith_tweet[3]}")
    print(f"Following Count:{ith_tweet[4]}")
    print(f"Follower Count:{ith_tweet[5]}")
    print(f"Total Tweets:{ith_tweet[6]}")
    print(f"Retweet Count:{ith_tweet[7]}")
    print(f"Tweet Text:{ith_tweet[8]}")
    print(f"Hashtags Used:{ith_tweet[9]}")

# %% [markdown]
# # Twarc Implementation (Preferred)

# %%
def scrape_twarc(users, numpages, keywords, start_date, end_date, filename):
    start_time = end_time = None
    if start_date:
        start_time = datetime.fromisoformat(start_date)
    if end_date:
        end_time = datetime.fromisoformat(end_date)
    if users:
        users_list = users.split()
        if len(users_list)>1:
            users = ' OR from:'.join(users_list)
        users = 'from:'+users
        users += ' '

    db = pd.DataFrame(columns=['username', 'description', 'date','time', 'following',
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags'])
    query = users+keywords
    print(query)
    search_results = t.search_all(query=query, start_time=start_time, end_time=end_time, max_results=numpages)
    i = 1
    for page in search_results:
        expansion = expansions.flatten(page)
        for tweet in expansion:
            username = tweet['author']['username']
            description = tweet['author']['description']
            date = tweet['created_at'][:10]
            time = tweet['created_at'][11:19]
            following = tweet['author']['public_metrics']['following_count']
            followers = tweet['author']['public_metrics']['followers_count']
            totaltweets = tweet['author']['public_metrics']['tweet_count']
            retweetcount = tweet['public_metrics']['retweet_count']
            if 'entities' in tweet.keys() and 'hashtags' in tweet['entities']:
                hashtags = [h['tag'] for h in tweet['entities']['hashtags']]
            else:
                hashtags = []
            text = tweet['text']
            text = re.sub("@[A-Za-z0-9_]+","", text)
            text = re.sub("#[A-Za-z0-9_]+", "", text)
            text = re.sub("http\S+","",text)
            ith_tweet = [username, description, date, time, following,
                         followers, totaltweets, retweetcount, text, hashtags]
            db.loc[len(db)] = ith_tweet

            #printtweetdata(i, ith_tweet) #Un-comment to print tweets
            i = i + 1
    db = db.iloc[db['text'].drop_duplicates().index,:]
    db.to_csv(filename)

# %%
t = Twarc2(bearer_token="AAAAAAAAAAAAAAAAAAAAAOnmVwEAAAAA8sbM8a%2BzFP0SAHqqmKr3wzlcNh8%3DMRoLllLhwNMPWP2f5VdNgfA0y32JnLY6zuaAr74BHEl7EJOrot")

# %%
#Debugging code
#search_results = t.search_all(query='from:wublockchain OR from:_checkmatey_ OR from:erikvoorhees OR from:brieflycrypto OR from:cryptoquant_com OR from:glassnode OR from:tbr90 OR from:woonomic OR from:rektcapital OR from:santimentfeed', max_results=10)

# %%
#expansions.flatten(search_results)

# %%
print("Enter usernames of interest (separated by spaces, without @):")
users = input()
print("Enter Number of Pages of Tweets to Scrape (Minimum 10)")
numpages = input()
print("(Optional) Enter keywords/hashtags for search (separated by OR)")
keywords = input()
print("(Optional) Enter start date (yyyy-mm-dd)")
start_date = input()
print("(Optional) Enter end date (yyyy-mm-dd)")
end_date = input()
print("Enter Output File Name")
filename = input()

start = time.time()
scrape_twarc(users, int(numpages), keywords, start_date, end_date, filename)
end = time.time()
print('Scraping has completed!')
print(str(end-start)+' seconds elapsed.')
# Out:
# Enter usernames of interest (separated by spaces, without @):
# brieflycrypto
# Enter Number of Pages of Tweets to Scrape (Minimum 10)
# 10
# (Optional) Enter keywords/hashtags for search (separated by OR)
# bitcoin
# (Optional) Enter start date (yyyy-mm-dd)
# 2022-04-01
# (Optional) Enter end date (yyyy-mm-dd)
# 2022-04-11
# Enter Output File Name
# timed_brieflycrypto.csv
# from:brieflycrypto bitcoin
# Scraping has completed!
# 28.264838695526123 seconds elapsed.

# %% [markdown]
# # Twarc Multi-API (not complete)

# %%
api_tokens = ["AAAAAAAAAAAAAAAAAAAAAOnmVwEAAAAA8sbM8a%2BzFP0SAHqqmKr3wzlcNh8%3DMRoLllLhwNMPWP2f5VdNgfA0y32JnLY6zuaAr74BHEl7EJOrot",
             "AAAAAAAAAAAAAAAAAAAAAGn2awEAAAAAyD8sjDE%2Bw4rG%2B0kij%2Bqr1i4i7Ss%3DHhsqcB3olsAOQtljZMrvh0UpjpTvxhqs79HM8N4JLN6s4KwG9R",
             "AAAAAAAAAAAAAAAAAAAAAB8VbAEAAAAATsLXbsc%2BmicF4gfY1RVh89nJrD0%3DEJPbazWZdgmWDdetN0ZnXPYLI9NmlN7JZU0voZDIxhdmEwDhDJ"]

# %%
twarc2_objs = [Twarc2(bearer_token = token) for token in api_tokens]

# %%
def twarc_multi_api(users, numpages, keywords, start_date, end_date, filename, twarc2_objs):
    start_time = end_time = None
    if start_date:
        start_time = datetime.fromisoformat(start_date)
    if end_date:
        end_time = datetime.fromisoformat(end_date)
    if users:
        users_list = users.split()
        if len(users_list)>1:
            users = ' OR from:'.join(users_list)
        users = 'from:'+users
        users += ' '

    db = pd.DataFrame(columns=['username', 'description', 'date','time', 'following',
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags'])
    query = users+keywords
    print(query)
    api_load = numpages//len(twarc2_objs)
    for num, client in enumerate(twarc2_objs):
        search_results[num] = client.search_all(query=query, start_time=start_time, end_time=end_time, max_results=numpages)
    i = 1
    for client in twarc2_objs:
        for page_num in range(api_load):
        expansion = expansions.flatten(page)
        for tweet in expansion:
            username = tweet['author']['username']
            description = tweet['author']['description']
            date = tweet['created_at'][:10]
            time = tweet['created_at'][11:19]
            following = tweet['author']['public_metrics']['following_count']
            followers = tweet['author']['public_metrics']['followers_count']
            totaltweets = tweet['author']['public_metrics']['tweet_count']
            retweetcount = tweet['public_metrics']['retweet_count']
            if 'entities' in tweet.keys() and 'hashtags' in tweet['entities']:
                hashtags = [h['tag'] for h in tweet['entities']['hashtags']]
            else:
                hashtags = []
            text = tweet['text']
            text = re.sub("@[A-Za-z0-9_]+","", text)
            text = re.sub("#[A-Za-z0-9_]+", "", text)
            text = re.sub("http\S+","",text)
            ith_tweet = [username, description, date, time, following,
                         followers, totaltweets, retweetcount, text, hashtags]
            db.loc[len(db)] = ith_tweet

            printtweetdata(i, ith_tweet)
            i = i + 1
        db = db.iloc[db['text'].drop_duplicates().index,:]
        
    db.to_csv(filename)

# %%
print("Enter usernames of interest (separated by spaces, without @):")
users = input()
print("Enter Number of Pages of Tweets to Scrape (Minimum 10)")
numpages = input()
print("(Optional) Enter keywords/hashtags for search (separated by OR)")
keywords = input()
print("(Optional) Enter start date (yyyy-mm-dd)")
start_date = input()
print("(Optional) Enter end date (yyyy-mm-dd)")
end_date = input()
print("Enter Output File Name")
filename = input()

start = time.time()
twarc_multi_api(users, int(numpages), keywords, start_date, end_date, filename)
end = time.time()
print('Scraping has completed!')
print(str(end-start)+' seconds elapsed.')

# %% [markdown]
# # Tweepy implementation below (Tweepy is deprecated)

# %%
# credentials for Academic Research Twitter API
consumer_key = "qBlrqapuTvDreZNzOdS8g4dnu"
consumer_secret = "jlaEzduOdHHEyR64sfJh2PJTg72kwXKR7IhPqawD6lJf3StgP2"
access_key = "1460353844395720704-UF1QRynvk3bnD4nU99KykutSrmvkRh"
access_secret = "5B7XYpSJ4qDFrLpK0GGNDxf2r66rfJVscrvwohwnyh11a"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
def scrape_tweepy(users, keywords, numtweet, filename):
    if users:
        users_list = users.split()
    else:
        return
    if keywords:
        keywords = keywords.split()
    db = pd.DataFrame(columns=['username', 'description', 'date', 'time', 'following',
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags'])
    num = 0
    for user in users_list:
        tweets = tweepy.Cursor(api.user_timeline, screen_name = user, lang="en", tweet_mode='extended').items(int(numtweet))
        print(tweets)
        list_tweets = [tweet for tweet in tweets]
        for i, tweet in enumerate(list_tweets):
            match = False
            for word in keywords:
                if word in tweet.full_text:
                    match = True
                    break
            if not match:
                del list_tweets[i]
                continue
            username = tweet.user.screen_name
            description = tweet.user.description
            date = str(tweet.created_at)[:10]
            time = str(tweet.created_at)[11:19]
            following = tweet.user.friends_count
            followers = tweet.user.followers_count
            totaltweets = tweet.user.statuses_count
            retweetcount = tweet.retweet_count
            hashtext = list()
            if 'hashtags' in tweet.entities.keys():
                hashtags = tweet.entities['hashtags']
                for j in range(0, len(hashtags)):
                    hashtext.append(hashtags[j]['text'])
            # in case of invalid reference in retweet, except block will be executed
            try:
                text = tweet.retweeted_status.full_text
            except AttributeError:
                text = tweet.full_text
            
            text = re.sub("@[A-Za-z0-9_]+","", text)
            text = re.sub("#[A-Za-z0-9_]+", "", text)
            ith_tweet = [username, description, date, time, following,
                         followers, totaltweets, retweetcount, text, hashtext]
            db.loc[len(db)] = ith_tweet
            printtweetdata(num, ith_tweet)
            num += 1

    db.to_csv(filename)

# %%
print("Enter usernames of interest (separated by spaces, without @):")
users = input()
print("Enter keywords/hashtags for search (separated by spaces)")
keywords = input()
print("Enter Number of Tweets to Scrape")
numtweet = input()
print("Enter Output File Name (.csv)")
filename = input()
scrape_tweepy(users, keywords, numtweet, filename)
print('Scraping has completed!')
# Out:
# Enter usernames of interest (separated by spaces, without @):
# brieflycrypto
# Enter keywords/hashtags for search (separated by spaces)
# bitcoin
# Enter Number of Tweets to Scrape
# 2000
# Enter Output File Name (.csv)
# brieflycrypto.csv
# ...
#
# Tweet 0:
# Username:BrieflyCrypto
# Description:Your #Crypto news feed 📰
#
# Telegram: https://t.co/ThOQOQLho1
# Created by @danclarkie in collaboration with @imBagsy
#
# 🚨 Articles are not endorsements 🚨
# Date:2022-04-09
# Time:13:40:15
# Following Count:3
# Follower Count:8799
# Total Tweets:19474
# Retweet Count:0
# Tweet Text:Mexico’s third-richest man Ricardo Salinas Pliego: "I have 60% in  and  equities and then 40% in hard-asset stock"
#
# Sentiment: Neutral
#
# Mexico's third-richest man and a strong bitcoin...
#
# Brief: https://t.co/zju72kUM6z
# https://t.co/xm7NMLvs38
# Hashtags Used:['Bitcoin', 'Bitcoin']
#
# Tweet 1:
# Username:BrieflyCrypto
# Description:Your #Crypto news feed 📰
#
# Telegram: https://t.co/ThOQOQLho1
# ...
